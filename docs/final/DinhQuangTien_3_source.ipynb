# %% [markdown]
# ## Khai báo các thư viện cần dùng

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score, r2_score
from sklearn.impute import SimpleImputer

from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, recall_score, f1_score

# %% [markdown]
# # Phần 1. Tiền xử lý dữ liệu

# %%
# Chạy trên môi trường colab
import kagglehub, os
path = kagglehub.dataset_download("kumarajarshi/life-expectancy-who")
df = pd.read_csv(os.path.join(path, 'Life Expectancy Data.csv'))

# Đọc dữ liệu từ file CSV
# file_path = '../data/Life Expectancy Data.csv'
# df = pd.read_csv(file_path)

# Loại bỏ khoảng trắng thừa trong tên cột
df.columns = df.columns.str.strip()

df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# ## 1.1 Ý nghĩa của các thuộc tính trong dữ liệu:

# %% [markdown]
# 1. Country: Tên quốc gia.
# 2. Year: Năm thu thập dữ liệu.
# 3. Status: Trạng thái phát triển (Developed/Developing).
# 4. Life expectancy: Tuổi thọ trung bình (đầu ra - target).
# 5. Adult Mortality: Tỷ lệ tử vong ở người lớn.
# 6. Infant deaths: Số trẻ sơ sinh tử vong trên 1000 dân.
# 7. Alcohol: Tiêu thụ rượu bình quân đầu người.
# 8. Percentage expenditure: Chi tiêu y tế chiếm phần trăm GDP.
# 9. Hepatitis B: Tỷ lệ tiêm chủng viêm gan B.
# 10. Measles: Số ca sởi trên 1000 dân.
# 11. BMI: Chỉ số khối cơ thể trung bình.
# 12. Under-five deaths: Số trẻ dưới 5 tuổi tử vong trên 1000 dân.
# 13. Polio: Tỷ lệ tiêm chủng bại liệt.
# 14. Total expenditure: Tổng chi tiêu y tế chiếm phần trăm GDP.
# 15. Diphtheria: Tỷ lệ tiêm chủng bạch hầu.
# 16. HIV/AIDS: Số ca tử vong do HIV/AIDS trên 1000 dân.
# 17. GDP: GDP bình quân đầu người.
# 18. Population: Dân số quốc gia.
# 19. Thinness 1-19 years: Tỷ lệ gầy ở trẻ 1-19 tuổi.
# 20. Thinness 5-9 years: Tỷ lệ gầy ở trẻ 5-9 tuổi.
# 21. Income composition of resources: Chỉ số phân bổ thu nhập.
# 22. Schooling: Số năm học trung bình.
#
# Các thuộc tính này dùng để dự đoán tuổi thọ trung bình dựa trên yếu tố y tế - xã hội.

# %% [markdown]
# Hiển thị kích thước của bảng dữ liệu

# %%
df.shape
# Out:
# (2938, 22)

# %% [markdown]
# Hiển thị thông tin tóm tắt về DataFrame df. Cụ thể cung cấp các thông tin sau:
# - Số hàng và số cột của df
# - Tên cột và loại dữ liệu tương ứng của từng cột
# - Số lượng giá trị không bị thiếu của từng cột
# - Tổng dung lượng bộ nhớ mà df sử dụng

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %% [markdown]
# Thống kê mô tả của target (Life expectancy)

# %%
df['Life expectancy'].describe()
# Out:
# count    2928.000000
# mean       69.224932
# std         9.523867
# min        36.300000
# 25%        63.100000
# 50%        72.100000
# 75%        75.700000
# max        89.000000
# Name: Life expectancy, dtype: float64

# %%
# VẼ BIỂU ĐỒ PHÂN BỐ TARGET
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogram + KDE
axes[0].hist(df['Life expectancy'].dropna(), bins=30, alpha=0.7, 
             color='steelblue', edgecolor='black')
axes[0].axvline(df['Life expectancy'].mean(), color='red', 
                linestyle='--', linewidth=2, label=f"Mean: {df['Life expectancy'].mean():.2f}")
axes[0].axvline(df['Life expectancy'].median(), color='green', 
                linestyle='--', linewidth=2, label=f"Median: {df['Life expectancy'].median():.2f}")
axes[0].set_xlabel('Life Expectancy (years)')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Phân bố tuổi thọ trung bình')
axes[0].legend()
axes[0].grid(alpha=0.3)

# Boxplot
box = axes[1].boxplot(df['Life expectancy'].dropna(), vert=True, patch_artist=True)
box['boxes'][0].set_facecolor('lightblue')
axes[1].set_ylabel('Life Expectancy (years)')
axes[1].set_title('Boxplot - Phát hiện outliers')
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# Lệnh df.isna().sum() trong pandas được sử dụng để kiểm tra số lượng giá trị bị thiếu (NaN - Not a Number) trong mỗi cột của DataFrame df. Cụ thể:
#
# df.isna(): Trả về một DataFrame với các giá
#
# - df.isna(): Trả về một DataFrame với các giá trị boolean, trong đó True chỉ ra giá trị bị thiếu (NaN) và False chỉ ra giá trị không bị thiếu.
# - sum(): Tổng hợp số lượng giá trị True (giá trị bị thiếu) trong mỗi cột. Kết quả là một danh sách cho biết số lượng giá trị thiếu trong từng cột của DataFrame.

# %%
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# Tính toán missing values
missing_before = df.isna().sum()
missing_count = missing_before.sum()

print(f"Tổng số missing values: {missing_count} ({missing_count/df.size*100:.2f}%)")
print(f"\nChi tiết missing values theo từng cột:")
print(missing_before[missing_before > 0].sort_values(ascending=False))
# Out:
# Tổng số missing values: 2563 (3.97%)
#
# Chi tiết missing values theo từng cột:
# Population                         652
# Hepatitis B                        553
# GDP                                448
# Total expenditure                  226
# Alcohol                            194
# Income composition of resources    167
# Schooling                          163
# thinness 5-9 years                  34
# thinness  1-19 years                34
# BMI                                 34
# Polio                               19
# Diphtheria                          19
# Life expectancy                     10
# Adult Mortality                     10
# dtype: int64

# %%
# VẼ 2 BIỂU ĐỒ MISSING VALUES (trên cùng 1 figure)
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Subplot 1: Heatmap
sns.heatmap(df.isnull(), cbar=True, yticklabels=False, cmap='viridis', ax=axes[0])
axes[0].set_title('Heatmap Missing Values\n(màu vàng = missing)', fontsize=12, pad=10)
axes[0].set_xlabel('Columns')

# Subplot 2: Bar chart
missing_df = missing_before[missing_before > 0].sort_values(ascending=False)
axes[1].bar(range(len(missing_df)), missing_df.values, color='coral', edgecolor='black', alpha=0.8)
axes[1].set_xticks(range(len(missing_df)))
axes[1].set_xticklabels(missing_df.index, rotation=45, ha='right')
axes[1].set_ylabel('Số lượng missing values')
axes[1].set_title('Số lượng giá trị thiếu theo từng cột', fontsize=12, pad=10)
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.2 Xử lý missing values

# %% [markdown]
# Xử lý giá trị thiếu (Missing Values)
#
# > **Công thức**:
# > $$
# \hat{x}_{ij} = \frac{1}{n} \sum_{k=1}^{n} x_{kj} \quad \text{(nếu dùng mean)}
# $$
#
# > **Chiến lược**: Dùng `SimpleImputer(strategy='mean')`

# %%
# Impute target trước
if df['Life expectancy'].isna().sum() > 0:
    target_mean = df['Life expectancy'].mean()
    target_imputer = SimpleImputer(strategy='mean')
    df['Life expectancy'] = target_imputer.fit_transform(df[['Life expectancy']])
    print(f"✓ Đã impute 'Life expectancy' bằng mean = {target_mean:.2f}")

# Impute numeric features
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
numeric_cols.remove('Life expectancy')
numeric_cols.remove('Year')

imputer_num = SimpleImputer(strategy='mean')
df[numeric_cols] = imputer_num.fit_transform(df[numeric_cols])
print(f"✓ Đã impute {len(numeric_cols)} features numeric bằng mean")

# Kiểm tra sau khi xử lý
missing_after = df.isnull().sum().sum()
print(f"\nMissing values sau xử lý: {missing_after}")
print(f"Đã xử lý thành công {missing_count - missing_after} missing values!")
# Out:
# ✓ Đã impute 'Life expectancy' bằng mean = 69.22
# ✓ Đã impute 18 features numeric bằng mean
#
# Missing values sau xử lý: 0
# Đã xử lý thành công 2563 missing values!

# %% [markdown]
# ## 1.3 Mã hóa categorical features

# %% [markdown]
# DROP 'Country' vì:
# - Có 193 unique values → tạo 192 dummy columns
# - Gây curse of dimensionality, overfitting
# - Country đã được thể hiện gián tiếp qua GDP, Schooling, Status, etc.

# %%
# DROP Country để tránh curse of dimensionality
df = df.drop('Country', axis=1)

# One-Hot Encoding cho Status (chỉ có 2 values: Developed/Developing)
print("\n One-Hot Encoding cho 'Status' (drop_first=True để tránh multicollinearity)")
print(f"  Trước encoding: Status có {df['Status'].nunique()} unique values")
df = pd.get_dummies(df, columns=['Status'], drop_first=True)
print(f"  Sau encoding: Tạo cột 'Status_Developing' (0=Developed, 1=Developing)")
# Out:
#  One-Hot Encoding cho 'Status' (drop_first=True để tránh multicollinearity)
#   Trước encoding: Status có 2 unique values
#   Sau encoding: Tạo cột 'Status_Developing' (0=Developed, 1=Developing)

# %% [markdown]
# Kích thước dữ liệu sau preprocessing

# %%
df.shape
# Out:
# (2938, 21)

# %% [markdown]
# In dữ liệu sau khi làm sạch (5 dòng đầu)

# %%
df.head()
# Out:
#    Year  Life expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0  2015             65.0            263.0           62.0     0.01
# 1  2014             59.9            271.0           64.0     0.01
# 2  2013             59.9            268.0           66.0     0.01
# 3  2012             59.5            272.0           69.0     0.01
# 4  2011             59.2            275.0           71.0     0.01
#
#    percentage expenditure  Hepatitis B  Measles   BMI  under-five deaths  ...  \
# 0               71.279624         65.0   1154.0  19.1               83.0  ...
# 1               73.523582         62.0    492.0  18.6               86.0  ...
# 2               73.219243         64.0    430.0  18.1               89.0  ...
# 3               78.184215         67.0   2787.0  17.6               93.0  ...
# 4                7.097109         68.0   3013.0  17.2               97.0  ...
#
#    Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# Tổng số features

# %%
print(f"\nTổng số features: {df.shape[1] - 1} (không tính target)")
# Out:
# Tổng số features: 20 (không tính target)

# %% [markdown]
# # Phần 2: Phân tích và trực quan hóa dữ liệu

# %% [markdown]
# ## 2.1. Tách đầu vào và đầu ra

# %% [markdown]
# - Loại bỏ Life expectancy khỏi df
# - axit = 1 --> xóa cột
# - Phần còn lại của df <-- X: các biến đầu vào để dự đoán đầu ra y là Life expectancy

# %%
# Tách đầu vào và đầu ra
X = df.drop(['Life expectancy'], axis=1)  # Loại bỏ target
y = df['Life expectancy']

# %% [markdown]
# Chia dữ liệu thành tập huấn luyện (training set) và tập kiểm tra (test set)
#
# train_test_split: Đây là hàm từ thư viện scikit-learn, được sử dụng để chia tập dữ liệu thành hai phần: tập huấn luyện và tập kiểm tra.
#
# test_size=0.3:
#
# - test_size chỉ định tỷ lệ dữ liệu sẽ được dùng làm tập kiểm tra.
# - Ở đây, test_size=0.3 có nghĩa là 30% dữ liệu sẽ được sử dụng cho tập kiểm tra, và 80% dữ liệu còn lại sẽ được dùng cho tập huấn luyện.
#
# random_state=42:
#
# - random_state là một tham số được sử dụng để đảm bảo tính tái lập (reproducibility).
# - Khi ta thiết lập random_state=42, việc chia dữ liệu sẽ luôn tạo ra cùng một kết quả mỗi khi bạn chạy mã, đảm bảo kết quả là nhất quán khi bạn thử lại.
# - Giá trị 42 không có ý nghĩa đặc biệt, nó chỉ là một số được dùng làm hạt ngẫu nhiên (random seed).
#
# Kết quả của train_test_split: Hàm này trả về bốn biến:
#
# - X_train: Tập đặc trưng huấn luyện, chứa 70% của X: gồm 70% mẫu dữ liệu của nhãn M, 70% mẫu dữ liệu của nhãn B.
# - X_test: Tập đặc trưng kiểm tra, chứa 30% của X: gồm 30% mẫu dữ liệu của nhãn M, 30% mẫu dữ liệu của nhãn B.
# - y_train: Tập nhãn huấn luyện, chứa 70% của y: là nhãn của X_train, tỷ lệ như trên.
# - y_test: Tập nhãn kiểm tra, chứa 30% của y.

# %%
# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %% [markdown]
# ## 2.2. Phân tích thành phần chính PCA

# %% [markdown]
# ### 2.2.1. Chuẩn hóa dữ liệu

# %% [markdown]
# Đoạn mã này sử dụng StandardScaler từ thư viện scikit-learn để chuẩn hóa dữ liệu. Việc chuẩn hóa là một bước rất quan trọng trong quy trình học máy, đặc biệt là đối với các mô hình nhạy cảm với sự khác biệt về đơn vị đo của các đặc trưng (như SVM, KNN, Logistic Regression,...).
#
# StandardScaler: Đây là một công cụ trong scikit-learn dùng để chuẩn hóa các đặc trưng của dữ liệu bằng cách tạo ra dữ liệu có phân phối chuẩn (normal distribution) với:
#
# Mean (trung bình) = 0.
# Standard Deviation (độ lệch chuẩn) = 1.
# Công thức chuẩn hóa
#
# Xét lần lượt từng cột thuộc tính, với mỗi giá trị ( x ) thì ta chuẩn hóa thành x_scaled như sau:
# $x_{\text{scaled}} = \frac{x - \mu}{\sigma}$
# Trong đó:
#
# ( x ) là giá trị của dữ liệu.
# ( N ) là số mẫu dữ liệu, ở đây cụ thể bằng 569.
# ( mu ) là giá trị trung bình của đặc trưng, được tính như sau:
#                     $$
#                     \mu = \frac{x1 + x2 + x3 + ... +xN}{N}
#                     $$
#
# ( sigma ) là độ lệch chuẩn của đặc trưng, được tính như sau:
#                     $$
#                     \sigma = \sqrt{\frac{1}{N} \sum_{i=1}^{N} (x_i - \mu)^2}
#                     $$

# %%
# Chuẩn hóa dữ liệu
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f"Đã chuẩn hóa: mean ≈ 0, std ≈ 1")
print(f"X_train_scaled: mean={X_train_scaled.mean():.6f}, std={X_train_scaled.std():.6f}")
# Out:
# Đã chuẩn hóa: mean ≈ 0, std ≈ 1
# X_train_scaled: mean=-0.000000, std=1.000000

# %% [markdown]
# ### 2.2.2. Thực hiện giảm chiều bằng PCA
# pca = PCA()
#
# - PCA(): Đây là cách khởi tạo một đối tượng của lớp PCA từ thư viện scikit-learn.
# - Khi khởi tạo PCA mà không truyền thêm tham số, PCA sẽ giữ lại tất cả các thành phần chính của dữ liệu.
#
# fit_transform(): Đây là một phương thức kết hợp hai bước trong quá trình PCA:
#
# - fit(): Phương thức này học các thành phần chính từ bộ dữ liệu huấn luyện (X_train_scaled). Nó sẽ tính toán ma trận hiệp phương sai của dữ liệu và tìm các thành phần chính.
# - transform(): Sau khi đã "học" xong các thành phần chính, phương thức transform() sẽ chiếu dữ liệu gốc vào không gian mới được tạo ra bởi các thành phần chính.

# %%
# Thực hiện PCA
pca = PCA()
X_train_pca = pca.fit_transform(X_train_scaled)

# %% [markdown]
# ### 2.2.3. Phân tích phương sai giải thích
# pca.explained_variance_ratio_:
#
# - Đây là thuộc tính của đối tượng PCA sau khi đã thực hiện fit() trên dữ liệu. Nó trả về tỷ lệ phương sai giải thích của mỗi thành phần chính.
# - Phương sai giải thích cho biết mức độ quan trọng của mỗi thành phần chính trong việc giải thích sự biến thiên trong dữ liệu.
#
# Kết quả explained_variance là một mảng chứa tỷ lệ phương sai giải thích của từng thành phần chính.
#
# np.cumsum(): Đây là hàm trong thư viện NumPy tính tổng dồn của một mảng. Cộng dồn các giá trị của explained_variance để tính tổng phương sai giải thích của tất cả các thành phần chính đến một thành phần chính cụ thể.
#
# cumulative_variance: Kết quả là một mảng chứa tổng phương sai giải thích tích lũy của các thành phần chính.

# %%
# Phân tích phương sai giải thích
explained_variance = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)

# %% [markdown]
# ### 2.2.4. Vẽ biểu đồ phương sai giải thích PCA.

# %% [markdown]
# Biểu đồ này sẽ giúp bạn hiểu được mức độ đóng góp của các thành phần chính trong PCA vào phương sai tổng thể, với một ngưỡng được chỉ ra để xác định số lượng thành phần chính cần thiết để giải thích ít nhất 95% phương sai của dữ liệu.

# %%
# Vẽ đồ thị phương sai giải thích
plt.figure(figsize=(10, 6))
plt.bar(range(1, len(explained_variance) + 1), explained_variance, alpha=0.5, align='center',
        label='Phương sai giải thích')
plt.step(range(1, len(cumulative_variance) + 1), cumulative_variance, where='mid',
         label='Phương sai tích lũy')
plt.axhline(y=0.95, color='r', linestyle='-', label='Ngưỡng 95%')
plt.xlabel('Số thành phần chính')
plt.ylabel('Tỉ lệ phương sai giải thích')
plt.title('Phương sai giải thích của các thành phần chính (PCA)')
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# ### 2.2.5. Xác định số thành phần chính cần để giữ 95% phương sai

# %% [markdown]
# cumulative_variance >= 0.95:
#
# - cumulative_variance là mảng chứa phương sai tích lũy của các thành phần chính (được tính bằng cách cộng dồn explained_variance).
# - Câu lệnh này kiểm tra điều kiện, trả về một mảng boolean (True/False), nơi mỗi giá trị tương ứng với việc liệu phương sai tích lũy ở đó có lớn hơn hoặc bằng 95% hay không.
#
# np.argmax()
#
# - np.argmax() trả về chỉ số (index) của phần tử đầu tiên có giá trị True trong mảng boolean được tạo ra từ điều kiện cumulative_variance >= 0.95.
# - Cộng 1 do np.argmax() trả về chỉ số bắt đầu từ 0, nhưng trong PCA, số thành phần chính bắt đầu từ 1

# %%
# Xác định số thành phần chính cần để giữ 95% phương sai
n_components_95 = np.argmax(cumulative_variance >= 0.95) + 1
print(f"Số thành phần chính cần để giữ 95% phương sai: {n_components_95}")
# Out:
# Số thành phần chính cần để giữ 95% phương sai: 15

# %%
# Áp dụng PCA với số thành phần được chọn
pca_95 = PCA(n_components=n_components_95)
X_train_pca_95 = pca_95.fit_transform(X_train_scaled)
X_test_pca_95 = pca_95.transform(X_test_scaled)

# %% [markdown]
# ### 2.2.6. Trực quan hóa dữ liệu PCA

# %% [markdown]
# Trực quan hóa dữ liệu sau khi áp dụng PCA bằng cách vẽ biểu đồ phân tán cho hai thành phần chính đầu tiên. Việc này giúp hình dung sự phân bố và mối quan hệ giữa các mẫu dữ liệu trong không gian giảm chiều.
#
# Màu sắc của các điểm dựa trên target y_train (numeric, dùng palette continuous) giúp ta thấy rõ sự gradient theo tuổi thọ.

# %%
# Trực quan hóa dữ liệu PCA
# Vẽ biểu đồ phân tán cho 2 thành phần chính đầu tiên
plt.figure(figsize=(9, 7))
scatter = plt.scatter(X_train_pca[:, 0], X_train_pca[:, 1], c=y_train, cmap='viridis', alpha=0.5)
plt.colorbar(scatter, label='Life Expectancy')
plt.xlabel('Thành phần chính 1')
plt.ylabel('Thành phần chính 2')
plt.title('Phân tán dữ liệu theo 2 thành phần chính đầu tiên (PCA)')
plt.tight_layout()

# %% [markdown]
# ## 2.3. Phân tích lựa chọn đặc trưng: SelectKBest

# %% [markdown]
# ### 2.3.1. Giới thiệu về SelectKBest

# %% [markdown]
# **SelectKBest** là một phương pháp **feature selection** (lựa chọn đặc trưng) thuộc loại **supervised learning**, có nghĩa là nó sử dụng thông tin từ biến mục tiêu (target) để đánh giá và chọn ra K features quan trọng nhất.
#
# Ưu điểm:
# - Giữ nguyên ý nghĩa của các features gốc (dễ diễn giải)
# - Giảm số chiều dữ liệu, tránh overfitting
# - Loại bỏ các features không có ý nghĩa thống kê
# - Tăng tốc độ training model
#
# Nhược điểm:
# - Không xử lý multicollinearity (tương quan cao giữa các features)
# - Đánh giá từng feature độc lập (không xem xét tương tác giữa các features)

# %% [markdown]
# ### 2.3.2. Phương pháp f_regression
#
# **f_regression** là hàm tính toán **F-statistic** giữa mỗi feature và target trong bài toán regression.
#
# #### Công thức F-statistic:
#
# $$
# F = \frac{\text{Variance giải thích bởi feature}}{\text{Variance còn lại (residual)}}
# $$
#
# Cụ thể hơn:
#
# $$
# F = \frac{MS_{regression}}{MS_{residual}} = \frac{SSR / 1}{SSE / (n-2)}
# $$
#
# Trong đó:
# - **SSR** (Sum of Squares Regression): Tổng bình phương do hồi quy
# - **SSE** (Sum of Squares Error): Tổng bình phương sai số
# - **n**: Số mẫu dữ liệu
#
# #### Ý nghĩa:
# - **F-statistic cao** → Feature có mối quan hệ tuyến tính mạnh với target
# - **F-statistic thấp** → Feature ít ảnh hưởng đến target
#
# ---

# %% [markdown]
# ### 2.3.3. Code thực hiện SelectKBest

# %% [markdown]
# #### Bước 1: Tính F-statistic cho tất cả features
# Giải thích:
# - SelectKBest: Class từ sklearn.feature_selection
# - score_func=f_regression: Sử dụng F-statistic làm tiêu chí đánh giá
# - k='all': Tính điểm cho tất cả features
# - fit(X_train_scaled, y_train): Tính F-statistic giữa từng feature và target

# %%
# SelectKBest với f_regression (phù hợp cho regression task)
# f_regression: tính F-statistic giữa mỗi feature và target
selector = SelectKBest(score_func=f_regression, k='all')
selector.fit(X_train_scaled, y_train)
# Out:
# SelectKBest(k='all', score_func=<function f_regression at 0x00000215CB15D6C0>)

# %% [markdown]
# #### Bước 2: Lấy điểm số và xếp hạng features
# Giải thích:
# - selector.scores_: Mảng numpy chứa F-statistic của từng feature
# - sort_values: Sắp xếp giảm dần theo điểm số
# - head(10): Hiển thị top 10 feature quan trọng nhất

# %%
# Lấy điểm số của từng feature
feature_scores = pd.DataFrame({
    'Feature': X.columns,
    'Score': selector.scores_
}).sort_values('Score', ascending=False)

print("\n✓ Top 10 features quan trọng nhất (theo F-statistic):")
print(feature_scores.head(10))
# Out:
# ✓ Top 10 features quan trọng nhất (theo F-statistic):
#                             Feature        Score
# 18                        Schooling  2186.352936
# 17  Income composition of resources  1953.288501
# 1                   Adult Mortality  1936.174684
# 12                         HIV/AIDS   935.386447
# 7                               BMI   926.685684
# 19                Status_Developing   613.135608
# 16               thinness 5-9 years   596.043992
# 15             thinness  1-19 years   590.594669
# 11                       Diphtheria   556.056202
# 9                             Polio   496.099644

# %% [markdown]
# #### Bước 3: Vẽ biểu đồ Feature Importance
# Giải thích:
# - plt.barh(): Biểu đồ cột ngang
# - invert_yaxis(): Đảo chiều để feature quan trọng nhất ở trên cùng
# - Feature có F-score cao → quan trọng hơn

# %%
# Vẽ biểu đồ feature importance
plt.figure(figsize=(12, 8))
plt.barh(range(len(feature_scores)), feature_scores['Score'], color='skyblue', edgecolor='black')
plt.yticks(range(len(feature_scores)), feature_scores['Feature'])
plt.xlabel('F-statistic Score')
plt.title('Feature Importance - SelectKBest (f_regression)')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Bước 4: Chọn K features tốt nhất
# Giải thích:
# - fit_transform(): Tính toán và chọn K feature tốt nhất
# - transform(): Áp dụng cùng phép chọn cho test set
# - Giúp giảm số chiều dữ liệu mà vẫn giữ thông tin quan trọng nhất

# %%
# Chọn K features tốt nhất (ví dụ: 10 features)
k_best = 10
selector_k = SelectKBest(score_func=f_regression, k=k_best)
X_train_kbest = selector_k.fit_transform(X_train_scaled, y_train)
X_test_kbest = selector_k.transform(X_test_scaled)

# %% [markdown]
# #### Bước 5: Lấy tên các features được chọn
# Giải thích:
# - get_support(): Trả về mảng boolean cho biết feature nào được chọn
# - X.columns[...]: Lấy tên cột tương ứng
# - Giúp biết chính xác các feature nào được giữ lại

# %%
# Lấy tên các features được chọn
selected_features = X.columns[selector_k.get_support()].tolist()

print(f"\n✓ Đã chọn {k_best} features tốt nhất:")
for i, feat in enumerate(selected_features, 1):
    print(f"{i}. {feat}")

print(f"\n✓ X_train_kbest shape: {X_train_kbest.shape}")
print(f"✓ X_test_kbest shape: {X_test_kbest.shape}")
# Out:
# ✓ Đã chọn 10 features tốt nhất:
# 1. Adult Mortality
# 2. BMI
# 3. Polio
# 4. Diphtheria
# 5. HIV/AIDS
# 6. thinness  1-19 years
# 7. thinness 5-9 years
# 8. Income composition of resources
# 9. Schooling
# 10. Status_Developing
#
# ✓ X_train_kbest shape: (2056, 10)
# ✓ X_test_kbest shape: (882, 10)

# %% [markdown]
# ### 2.3.4. Trực quan hóa Correlation Matrix
# Ý nghĩa:
# - Hiển thị mối tương quan giữa các feature được chọn và target
# - Nếu có nhiều cặp feature tương quan mạnh (|r| > 0.8) → multicollinearity cao

# %%
# Trực quan hóa correlation matrix của K features được chọn
X_train_kbest_df = pd.DataFrame(X_train_kbest, columns=selected_features)
X_train_kbest_df['Life_expectancy'] = y_train.values

plt.figure(figsize=(12, 10))
correlation_matrix = X_train_kbest_df.corr()
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', 
            square=True, linewidths=0.5, cbar_kws={"shrink": 0.8})
plt.title(f'Correlation Matrix - Top {k_best} Features (SelectKBest)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3.5. Vẽ scatter plots cho Top 4 features
# Giải thích:
# - Quan sát mối quan hệ giữa top 4 features quan trọng nhất và target
# - Pattern càng rõ → F-score càng cao

# %%
# Vẽ scatter plots cho top 4 features vs Life expectancy
top_4_features = feature_scores.head(4)['Feature'].tolist()

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

for i, feature in enumerate(top_4_features):
    feat_idx = X.columns.tolist().index(feature)
    axes[i].scatter(X_train_scaled[:, feat_idx], y_train, alpha=0.5, s=20)
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Life Expectancy (years)')
    axes[i].set_title(f'{feature} vs Life Expectancy\n(F-score: {feature_scores[feature_scores["Feature"]==feature]["Score"].values[0]:.2f})')
    axes[i].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.4. So sánh và đánh giá

# %%
# 4.1 Đánh giá phương sai giải thích trên tập kiểm tra
X_test_reconstructed_pca = np.dot(X_test_pca_95, pca_95.components_) + scaler.mean_
pca_variance_score = explained_variance_score(X_test_scaled, X_test_reconstructed_pca)

print("\n So sánh hai phương pháp giảm chiều:")
print("-" * 80)
print(f"PCA:")
print(f"  - Số chiều sau giảm: {n_components_95}")
print(f"  - Phương sai giải thích (test set): {pca_variance_score:.4f}")
print(f"  - Loại: Unsupervised (không dùng target)")
print(f"  - Ưu điểm: Giữ được variance, giảm multicollinearity")
print(f"  - Nhược điểm: Mất tính diễn giải của features gốc")

print(f"\nSelectKBest:")
print(f"  - Số chiều sau giảm: {k_best}")
print(f"  - Phương pháp: F-statistic (f_regression)")
print(f"  - Loại: Supervised (dùng target để chọn features)")
print(f"  - Ưu điểm: Giữ nguyên features gốc, dễ diễn giải")
print(f"  - Nhược điểm: Không xử lý multicollinearity")
# Out:
#  So sánh hai phương pháp giảm chiều:
# --------------------------------------------------------------------------------
# PCA:
#   - Số chiều sau giảm: 15
#   - Phương sai giải thích (test set): 0.9655
#   - Loại: Unsupervised (không dùng target)
#   - Ưu điểm: Giữ được variance, giảm multicollinearity
#   - Nhược điểm: Mất tính diễn giải của features gốc
#
# SelectKBest:
#   - Số chiều sau giảm: 10
#   - Phương pháp: F-statistic (f_regression)
#   - Loại: Supervised (dùng target để chọn features)
#   - Ưu điểm: Giữ nguyên features gốc, dễ diễn giải
#   - Nhược điểm: Không xử lý multicollinearity

# %% [markdown]
# ## 2.5. Trực quan hóa các thành phần chính quan trọng

# %%
# Trực quan hóa các thành phần chính quan trọng
if n_components_95 >= 6:
    # Vẽ biểu đồ phân tán cho 6 thành phần chính đầu tiên (cặp đôi)
    fig, axes = plt.subplots(2, 3, figsize=(16, 10))
    axes = axes.flatten()

    pairs = [(0, 1), (2, 3), (4, 5), (0, 2), (1, 3), (0, 4)]

    for i, (pc1, pc2) in enumerate(pairs):
        scatter = axes[i].scatter(X_train_pca[:, pc1], X_train_pca[:, pc2], c=y_train, cmap='viridis', alpha=0.5)
        axes[i].set_xlabel(f'PC {pc1+1}')
        axes[i].set_ylabel(f'PC {pc2+1}')
        axes[i].set_title(f'PC {pc1+1} vs PC {pc2+1}')

    plt.tight_layout()
    plt.colorbar(scatter, ax=axes, label='Life expectancy')

# %%
# Phân tích mối quan hệ giữa các thành phần chính và các đặc trưng gốc
pca_components = pd.DataFrame(
    pca.components_,
    columns=X.columns
)

plt.figure(figsize=(19, 9))
sns.heatmap(pca_components.iloc[:n_components_95], annot=True, cmap='coolwarm', 
            fmt='.2f', linewidths=0.5)
plt.xlabel('Đặc trưng gốc')
plt.ylabel('Thành phần chính')
plt.title('Mối quan hệ giữa thành phần chính và đặc trưng gốc')
plt.tight_layout()

# %% [markdown]
# # Phần 3: Các mô hình hồi quy

# %% [markdown]
# ## 3.1. K-nearest neighbors - KNN

# %% [markdown]
# K-nearest neighbor là một trong những thuật toán supervised-learning đơn giản nhất (mà hiệu quả trong một vài trường hợp) trong Machine Learning. Khi training, thuật toán này không học một điều gì từ dữ liệu training (đây cũng là lý do thuật toán này được xếp vào loại lazy learning), mọi tính toán được thực hiện khi nó cần dự đoán kết quả của dữ liệu mới. K-nearest neighbor có thể áp dụng được vào cả hai loại của bài toán Supervised learning là Classification và Regression. Chúng ta sẽ áp dụng thuật toán KNN vào bài toán dự đoán tuổi thọ trung bình:
#
#
# -Khoảng cách ta sẽ sử dụng công thức Manhattan (L1-norm):
# $$
# d(\mathbf{x}_i, \mathbf{x}_j) = \sum_{k=1}^{n} |x_{ik} - x_{jk}|
# $$
# Trong đó:
# - $ \mathbf{x}_i, \mathbf{x}_j $: hai vector đặc trưng
# -  n : số chiều (số đặc trưng)
#
# -Mục tiêu ta sẽ cố gắng tìm được k phần tử gần nhất rồi đưa ra dự đoán
#
#
# Trong dự án, chúng ta áp dụng trên:
# - Dữ liệu gốc (sau scale, ~20 features).
# - Dữ liệu PCA (giảm chiều, giữ 95% variance để tránh overfit).
# - Dữ liệu Select K Best (giảm chiều với khoảng 10 chiều tốt nhất)

# %%
#Khai báo thư viện
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import mean_squared_error, r2_score,root_mean_squared_error
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# Overfit: Mô hình học quá tốt trên train → Train R² cao, Test R² thấp
#
# Công thức kiểm tra:
# - Nếu ΔR² > 0.05: Có dấu hiệu overfit
# - Nếu ΔR² > 0.1: Overfit nặng

# %%
# Hàm đánh giá mô hình
results_knn=[]

def evaluate_knn(model, X_train, X_test, y_train, y_test, name, ratio_name):
    
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)

    
    train_r2 = r2_score(y_train, train_pred)
    test_r2 = r2_score(y_test, test_pred)
    train_mse = mean_squared_error(y_train, train_pred)
    test_mse = mean_squared_error(y_test, test_pred)
    
    rmse = root_mean_squared_error(test_pred,y_test)
    delta_r2 = train_r2 - test_r2
    overfit = "Có" if delta_r2 > 0.05  else "Không"
    d = {
        'Tỉ lệ': ratio_name,
        'Dữ liệu': name,
        'Train R²': round(train_r2, 4),
        'Test R²': round(test_r2, 4),       
        'ΔR²': round(delta_r2, 4),
        'Train MSE': round(train_mse, 4),
        'Test MSE': round(test_mse, 4),
        'RMSE': round(rmse,4),
        'Overfit': overfit
    }
    results_knn.append(d)
    print(d)
    # test_r2
    return test_pred

# %%
# Danh sách tỉ lệ chia
split_ratios = [
    (0.8, 0.2, "80:20 (4:1)"),
    (0.7, 0.3, "70:30 (7:3)"),
    (0.6, 0.4, "60:40 (6:4)")
]

# %%
# Hàm trực quan hóa phần dư 
from typing import Tuple, Union


def plot_residuals_single_split(
    y_test: Union[np.ndarray, pd.Series],
    y_pred: Union[np.ndarray, pd.Series],
    ratio_label: str = "",
    figsize: Tuple[int, int] = (6, 4)
):
    y_test = np.array(y_test)
    y_pred = np.array(y_pred)

    # Tính phần dư
    residuals = y_test - y_pred

    # Tính các thống kê
    mean_res = np.mean(residuals)
    var_res = np.var(residuals)

    # In ra màn hình
    print(f"[Train:Test = {ratio_label}]")
    print(f"  Mean residual  = {mean_res:.4f}")
    print(f"  Variance       = {var_res:.4f}")
    print(f"  Std deviation  = {np.std(residuals):.4f}")

    # Vẽ biểu đồ phần dư
    plt.figure(figsize=figsize)
    plt.scatter(y_pred, residuals, alpha=0.6, color='royalblue', edgecolor='white')
    plt.axhline(0, color='red', linestyle='--')
    plt.title(f"Residuals Plot (Train:Test = {ratio_label})")
    plt.xlabel("Giá trị dự đoán (y_pred)")
    plt.ylabel("Phần dư (y_test - y_pred)")

    # Ghi chú Mean và Var trên biểu đồ
    plt.text(
        0.05, 0.9,
        f"Mean = {mean_res:.2f}\nVar = {var_res:.2f}",
        transform=plt.gca().transAxes,
        fontsize=10,
        bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray')
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 3.1.1 Hồi quy với dữ liệu gốc
# - Sử dụng tất cả các features sau chuẩn hóa (X_scaled ~ 20)
# - Fit mô hình
# - Predict và đánh giá trên train/test
# - Ta sẽ lấy k theo công thức k = $\sqrt{n}$

# %%
print("Bắt đầu với DỮ LIỆU GỐC\n" + "="*50)
for train_size, test_size, ratio_name in split_ratios:
    print(f"\nTỉ lệ: {ratio_name}")
    temp =  ratio_name.split()
    print(temp)
    # Chia dữ liệu
    X_train_orig_knn, X_test_orig_knn, y_train_orig_knn, y_test_orig_knn = train_test_split(
        X, y, train_size=train_size, random_state=25
    )

    # Chuẩn hóa (fit trên train, transform trên test)
    scaler = StandardScaler()
    X_train_scaled_knn = scaler.fit_transform(X_train_orig_knn)
    X_test_scaled_knn = scaler.transform(X_test_orig_knn)

    # Huấn luyện mô hình hồi quy
    k = max(1, int(np.sqrt(len(X_train_orig_knn))))
    print(f"   k = {k}")

    knn = KNeighborsRegressor(n_neighbors=k, weights="uniform", metric="manhattan")
    knn.fit(X_train_scaled_knn, y_train_orig_knn)

    y_pred_origin_knn = []
    # Đánh giá
    y_pred_origin_knn = evaluate_knn(knn, X_train_scaled_knn, X_test_scaled_knn, y_train_orig_knn, y_test_orig_knn, "Dữ liệu gốc", ratio_name)
    
    #Vẽ biểu đồ phần dư 
    plot_residuals_single_split(y_test_orig_knn,y_pred_origin_knn,temp[0])
# Out:
# Bắt đầu với DỮ LIỆU GỐC
# ...
#
# Tỉ lệ: 80:20 (4:1)
# ['80:20', '(4:1)']
#    k = 48
# {'Tỉ lệ': '80:20 (4:1)', 'Dữ liệu': 'Dữ liệu gốc', 'Train R²': 0.8982, 'Test R²': 0.8758, 'ΔR²': 0.0224, 'Train MSE': 8.9641, 'Test MSE': 12.3597, 'RMSE': 3.5156, 'Overfit': 'Không'}
# [Train:Test = 80:20]
#   Mean residual  = -0.5538
#   Variance       = 12.0529
#   Std deviation  = 3.4717
# Tỉ lệ: 70:30 (7:3)
# ['70:30', '(7:3)']
#    k = 45
# {'Tỉ lệ': '70:30 (7:3)', 'Dữ liệu': 'Dữ liệu gốc', 'Train R²': 0.8967, 'Test R²': 0.8718, 'ΔR²': 0.0249, 'Train MSE': 9.0967, 'Test MSE': 12.271, 'RMSE': 3.503, 'Overfit': 'Không'}
# [Train:Test = 70:30]
#   Mean residual  = -0.4986
#   Variance       = 12.0224
#   Std deviation  = 3.4673
# Tỉ lệ: 60:40 (6:4)
# ['60:40', '(6:4)']
#    k = 41
# {'Tỉ lệ': '60:40 (6:4)', 'Dữ liệu': 'Dữ liệu gốc', 'Train R²': 0.8963, 'Test R²': 0.877, 'ΔR²': 0.0193, 'Train MSE': 9.2961, 'Test MSE': 11.2456, 'RMSE': 3.3535, 'Overfit': 'Không'}
# [Train:Test = 60:40]
# ...

# %% [markdown]
# ### 3.1.2 Hồi quy với dữ liệu giảm chiều
# - Sử dụng X_pca (giảm từ ~20 xuống ~8-10 components, giữ 95% variance).

# %%
print("\nBắt đầu với DỮ LIỆU PCA\n" + "="*50)

for train_size, test_size, ratio_name in split_ratios:
    print(f"\nTỉ lệ: {ratio_name}")
    temp = ratio_name.split()
    X_train_pca_knn, X_test_pca_knn, y_train_pca_knn, y_test_pca_knn = train_test_split(
        X, y, train_size=train_size,random_state=25
    )
    # Chuẩn hóa dữ liệu
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_pca_knn)
    X_test_scaled = scaler.transform(X_test_pca_knn)

    pca_full = PCA()
    pca_full.fit(X_train_scaled)
    cumvar = np.cumsum(pca_full.explained_variance_ratio_)
    n_comp = np.argmax(cumvar >= 0.95) + 1
    print(f"   Số components giữ 95% variance: {n_comp}")

    pca_95 = PCA(n_components=n_comp)
    X_train_pca = pca_95.fit_transform(X_train_scaled)
    X_test_pca = pca_95.transform(X_test_scaled)
    
    k = max(1, int(np.sqrt(len(X_train_pca_knn))))
    knn_pca = KNeighborsRegressor(n_neighbors=k, weights="uniform", metric="manhattan")
    knn_pca.fit(X_train_pca, y_train_pca_knn)

    y_pred_pca_knn = []
    y_pred_pca_knn= evaluate_knn(knn_pca, X_train_pca, X_test_pca, y_train_pca_knn, y_test_pca_knn, "Dữ liệu PCA", ratio_name)

    #Vẽ trục quan hóa
    plot_residuals_single_split(y_test_pca_knn,y_pred_pca_knn,temp[0])
# Out:
# Bắt đầu với DỮ LIỆU PCA
# ...
#
# Tỉ lệ: 80:20 (4:1)
#    Số components giữ 95% variance: 15
# {'Tỉ lệ': '80:20 (4:1)', 'Dữ liệu': 'Dữ liệu PCA', 'Train R²': 0.8531, 'Test R²': 0.8348, 'ΔR²': 0.0183, 'Train MSE': 12.9346, 'Test MSE': 16.4362, 'RMSE': 4.0542, 'Overfit': 'Không'}
# [Train:Test = 80:20]
#   Mean residual  = -0.3587
#   Variance       = 16.3075
#   Std deviation  = 4.0383
# Tỉ lệ: 70:30 (7:3)
#    Số components giữ 95% variance: 15
# {'Tỉ lệ': '70:30 (7:3)', 'Dữ liệu': 'Dữ liệu PCA', 'Train R²': 0.8514, 'Test R²': 0.8306, 'ΔR²': 0.0208, 'Train MSE': 13.0837, 'Test MSE': 16.2091, 'RMSE': 4.026, 'Overfit': 'Không'}
# [Train:Test = 70:30]
#   Mean residual  = -0.2482
#   Variance       = 16.1475
#   Std deviation  = 4.0184
# Tỉ lệ: 60:40 (6:4)
#    Số components giữ 95% variance: 15
# {'Tỉ lệ': '60:40 (6:4)', 'Dữ liệu': 'Dữ liệu PCA', 'Train R²': 0.847, 'Test R²': 0.8325, 'ΔR²': 0.0145, 'Train MSE': 13.7199, 'Test MSE': 15.3172, 'RMSE': 3.9137, 'Overfit': 'Không'}
# ...

# %% [markdown]
# - Sử dụng X_slkb (giảm từ 20 chiều xuống 10 chiều )

# %%
print("\nBắt đầu với DỮ LIỆU SelectKbest\n" + "="*50)

for train_size, test_size, ratio_name in split_ratios:
    print(f"\nTỉ lệ: {ratio_name}")
    temp = ratio_name.split()
    
    X_train_slkb_knn, X_test_slkb_knn, y_train_slkb_knn, y_test_slkb_knn = train_test_split(
        X, y, train_size=train_size,random_state=25
    )
    #Chuẩn hóa dữ liệu
    scaler = StandardScaler()
    X_train_slkb_scaled = scaler.fit_transform(X_train_slkb_knn)
    X_test_slkb_scaled = scaler.transform(X_test_slkb_knn)
 
    select = SelectKBest(score_func=f_regression, k='all')
    select.fit(X_train_slkb_scaled, y_train_slkb_knn)

    k_best_knn = 10
    select_k = SelectKBest(score_func=f_regression,k=k_best_knn)
    X_train_slkb = select_k.fit_transform(X_train_slkb_scaled,y_train_slkb_knn)
    X_test_slkb = select_k.transform(X_test_slkb_scaled)

    k = max(1, int(np.sqrt(len(X_train_slkb_knn))))
    knn_slkb = KNeighborsRegressor(n_neighbors=k,weights="uniform",metric="manhattan")
    knn_slkb.fit(X_train_slkb,y_train_slkb_knn)
    print()
    y_pred_slkb_knn = []
    y_pred_slkb_knn= evaluate_knn(knn_slkb, X_train_slkb, X_test_slkb, y_train_slkb_knn, y_test_slkb_knn, "Dữ liệu Select KBest", ratio_name)
    print("="*50)
    plot_residuals_single_split(y_test_slkb_knn,y_pred_slkb_knn,temp[0])
# Out:
# Bắt đầu với DỮ LIỆU SelectKbest
# ...
#
# Tỉ lệ: 80:20 (4:1)
#
# {'Tỉ lệ': '80:20 (4:1)', 'Dữ liệu': 'Dữ liệu Select KBest', 'Train R²': 0.8995, 'Test R²': 0.8832, 'ΔR²': 0.0162, 'Train MSE': 8.8528, 'Test MSE': 11.6199, 'RMSE': 3.4088, 'Overfit': 'Không'}
# ...
# [Train:Test = 80:20]
#   Mean residual  = -0.7368
#   Variance       = 11.0771
#   Std deviation  = 3.3282
# Tỉ lệ: 70:30 (7:3)
#
# {'Tỉ lệ': '70:30 (7:3)', 'Dữ liệu': 'Dữ liệu Select KBest', 'Train R²': 0.8986, 'Test R²': 0.882, 'ΔR²': 0.0166, 'Train MSE': 8.9228, 'Test MSE': 11.2931, 'RMSE': 3.3605, 'Overfit': 'Không'}
# ...
# [Train:Test = 70:30]
#   Mean residual  = -0.6741
#   Variance       = 10.8386
#   Std deviation  = 3.2922
# Tỉ lệ: 60:40 (6:4)
#
# {'Tỉ lệ': '60:40 (6:4)', 'Dữ liệu': 'Dữ liệu Select KBest', 'Train R²': 0.8976, 'Test R²': 0.886, 'ΔR²': 0.0116, 'Train MSE': 9.1787, 'Test MSE': 10.4247, 'RMSE': 3.2287, 'Overfit': 'Không'}
# ...
# [Train:Test = 60:40]
#   Mean residual  = -0.5483
#   Variance       = 10.1241
# ...

# %% [markdown]
# ### So sánh nhận xét và đánh giá kết quả

# %%
# Tạo bảng kết quả
results_df_knn = pd.DataFrame(results_knn)
display(results_df_knn)
# Out:
#          Tỉ lệ               Dữ liệu  Train R²  Test R²     ΔR²  Train MSE  \
# 0  80:20 (4:1)           Dữ liệu gốc    0.8982   0.8758  0.0224     8.9641
# 1  70:30 (7:3)           Dữ liệu gốc    0.8967   0.8718  0.0249     9.0967
# 2  60:40 (6:4)           Dữ liệu gốc    0.8963   0.8770  0.0193     9.2961
# 3  80:20 (4:1)           Dữ liệu PCA    0.8531   0.8348  0.0183    12.9346
# 4  70:30 (7:3)           Dữ liệu PCA    0.8514   0.8306  0.0208    13.0837
# 5  60:40 (6:4)           Dữ liệu PCA    0.8470   0.8325  0.0145    13.7199
# 6  80:20 (4:1)  Dữ liệu Select KBest    0.8995   0.8832  0.0162     8.8528
# 7  70:30 (7:3)  Dữ liệu Select KBest    0.8986   0.8820  0.0166     8.9228
# 8  60:40 (6:4)  Dữ liệu Select KBest    0.8976   0.8860  0.0116     9.1787
#
#    Test MSE    RMSE Overfit
# 0   12.3597  3.5156   Không
# 1   12.2710  3.5030   Không
# 2   11.2456  3.3535   Không
# 3   16.4362  4.0542   Không
# 4   16.2091  4.0260   Không
# 5   15.3172  3.9137   Không
# ...

# %%
plt.figure(figsize=(14, 8))

# Biểu đồ R² theo tỉ lệ
sns.set_style("whitegrid")
results_plot = results_df_knn[results_df_knn['Dữ liệu'].str.contains('gốc|PCA|Select KBest') & ~results_df_knn['Dữ liệu'].str.contains('Ridge|Lasso')]

sns.lineplot(data=results_plot, x='Tỉ lệ', y='Test R²', hue='Dữ liệu', marker='o', linewidth=2.5)
plt.title('So sánh Test R² theo tỉ lệ chia dữ liệu', fontsize=16)
plt.ylabel('Test R²')
plt.xlabel('Tỉ lệ Train:Validation')
plt.legend(title='Dữ liệu')
plt.tight_layout()
plt.show()

# %%
# Biểu đồ ΔR² theo tỉ lệ
plt.figure(figsize=(10, 6))
sns.barplot(data=results_df_knn, x='Tỉ lệ', y='ΔR²', hue='Dữ liệu', palette='husl')
plt.axhline(0.05, color='red', linestyle='--', label='Ngưỡng overfit')
plt.title('So sánh độ chênh lệch R² (ΔR²) theo tỉ lệ chia')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Lọc dữ liệu
df_orig = results_df_knn[results_df_knn['Dữ liệu'].str.contains('gốc')]
df_pca  = results_df_knn[results_df_knn['Dữ liệu'].str.contains('PCA')]
df_slkb = results_df_knn[results_df_knn['Dữ liệu'].str.contains('Select KBest')]

# Tính trung bình ΔR²
mean_orig = df_orig['ΔR²'].mean()
mean_pca  = df_pca['ΔR²'].mean()
mean_slkb = df_slkb['ΔR²'].mean()

# % giảm
percent_reduction_pca = ((mean_orig - mean_pca) / mean_orig) * 100
percent_reduction_slkb = ((mean_orig - mean_slkb) / mean_orig) * 100


print(f"ΔR² trung bình (dữ liệu gốc): {mean_orig:.4f}")
print(f"ΔR² trung bình (dữ liệu PCA):  {mean_pca:.4f}")
print(f"ΔR² trung bình (dữ liệu Select KBest):  {mean_slkb:.4f}")
print(f"PCA giúp giảm ΔR²: {percent_reduction_pca:.1f}%")
print(f"Select Kbest giúp giảm ΔR²: {percent_reduction_slkb: .1f}%")
# Out:
# ΔR² trung bình (dữ liệu gốc): 0.0222
# ΔR² trung bình (dữ liệu PCA):  0.0179
# ΔR² trung bình (dữ liệu Select KBest):  0.0148
# PCA giúp giảm ΔR²: 19.5%
# Select Kbest giúp giảm ΔR²:  33.3%

# %% [markdown]
# Nhận xét:
#
# - Kết quả cho thấy phương pháp SelectKBest là hiệu quả nhất trong việc cân bằng giữa độ chính xác và độ ổn định của mô hình KNN.
#
# - PCA tuy giúp mô hình ổn định hơn nhưng giảm độ chính xác do mất mát thông tin.
#
# - Dữ liệu gốc vẫn cho kết quả tốt nhưng có độ chênh lớn hơn, nên không tối ưu bằng SelectKBest.

# %% [markdown]
# ## 3.2. Linear Regression

# %% [markdown]
# Kiến thức cơ bản
# Hồi quy tuyến tính (Linear Regression) là một mô hình học máy cơ bản dùng để dự đoán giá trị liên tục (continuous) dựa trên các đặc trưng đầu vào. Trong dự án này, chúng ta sử dụng nó để dự đoán tuổi thọ trung bình (Life expectancy) – một biến số liên tục (từ khoảng 40-80 năm).
#
# Mục tiêu: Tìm một hàm tuyến tính $y = \beta_0 + \beta_1 x_1 + \beta_2 x_2 + \dots + \beta_p x_p + \epsilon$ sao cho dự đoán $\hat{y}$ gần với $y$ thực tế nhất.
#
# - $y$: Giá trị thực (target).
# - $x_i$: Đặc trưng (features, ví dụ: GDP, Schooling).
# - $\beta_0$: Hệ số chặn (intercept).
# - $\beta_i$: Hệ số hồi quy (coefficients) – thể hiện mức độ ảnh hưởng của $x_i$ đến $y$.
# - $\epsilon$: Sai số ngẫu nhiên (noise).
#
# Phương pháp ước lượng: Ordinary Least Squares (OLS) – tối thiểu hóa tổng bình phương sai số (RSS: Residual Sum of Squares):
#
# $RSS = \sum_{i=1}^n (y_i - \hat{y}_i)^2$
#
# Giải bằng ma trận: $\hat{\beta} = (X^T X)^{-1} X^T y$, với $X$ là ma trận đặc trưng (thêm cột 1 cho intercept).
#
# Trong dự án, chúng ta áp dụng trên:
#
# - Dữ liệu gốc (sau scale, ~20 features).
# - Dữ liệu PCA (giảm chiều, giữ 95% variance để tránh overfit).
#
# Đánh giá:
#
# - R² (Coefficient of Determination): $R^2 = 1 - \frac{RSS}{TSS}$, với TSS = tổng phương sai. Giá trị gần 1: mô hình giải thích tốt dữ liệu.
# - MSE (Mean Squared Error): $MSE = \frac{1}{n} \sum (y_i - \hat{y}_i)^2$. Càng nhỏ càng tốt.
#
# Overfit: Nếu Train R² >> Test R², mô hình học "thuộc lòng" train data, kém trên data mới. Nguyên nhân: Quá nhiều features, noise.

# %%
# Khai báo thư viện
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# Overfit: Mô hình học quá tốt trên train → Train R² cao, Test R² thấp
#
# Công thức kiểm tra:
# - Nếu ΔR² > 0.05: Có dấu hiệu overfit
# - Nếu ΔR² > 0.1: Overfit nặng

# %%
# Hàm đánh giá mô hình
results = []

def evaluate_lr(model, X_train, X_test, y_train, y_test, name, ratio_name):
    
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)
    
    train_r2 = r2_score(y_train, train_pred)
    test_r2 = r2_score(y_test, test_pred)
    train_mse = mean_squared_error(y_train, train_pred)
    test_mse = mean_squared_error(y_test, test_pred)
    
    delta_r2 = train_r2 - test_r2
    overfit = "Có" if delta_r2 > 0.05 else "Không"
    d = {
        'Tỉ lệ': ratio_name,
        'Dữ liệu': name,
        'Train R²': round(train_r2, 4),
        'Test R²': round(test_r2, 4),
        'ΔR²': round(delta_r2, 4),
        'Train MSE': round(train_mse, 4),
        'Test MSE': round(test_mse, 4),
        'Overfit': overfit
    }
    results.append(d)
    print(d)
    return test_pred

# %%
# Danh sách tỉ lệ chia
split_ratios = [
    (0.8, 0.2, "80:20 (4:1)"),
    (0.7, 0.3, "70:30 (7:3)"),
    (0.6, 0.4, "60:40 (6:4)")
]

# %% [markdown]
# ### 3.2.1 Hồi quy với dữ liệu gốc

# %% [markdown]
# - Sử dụng tất cả features sau chuẩn hóa (X_scaled: ~20 chiều).
# - Fit mô hình: LinearRegression().fit(X_train, y_train).
# - Predict và đánh giá trên train/test.
# - Công thức dự đoán: $\hat{y} = \hat{\beta}_0 + \sum \hat{\beta}_i x_i$.

# %%
print("Bắt đầu với DỮ LIỆU GỐC\n" + "="*50)
for train_size, test_size, ratio_name in split_ratios:
    print(f"\nTỉ lệ: {ratio_name}")
    
    # Chia dữ liệu
    X_train_orig, X_test_orig, y_train_orig, y_test_orig = train_test_split(
        X, y, train_size=train_size, random_state=90
    )

    # Chuẩn hóa (fit trên train, transform trên test)
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_orig)
    X_test_scaled = scaler.transform(X_test_orig)

    # Huấn luyện mô hình hồi quy
    lr = LinearRegression()
    lr.fit(X_train_scaled, y_train_orig)

    # Đánh giá
    y_pred_orig = []
    y_pred_orig = evaluate_lr(lr, X_train_scaled, X_test_scaled, y_train_orig, y_test_orig, "Dữ liệu gốc", ratio_name)
    #Vẽ trục quan hóa
    temp = ratio_name.split()
    plot_residuals_single_split(y_test_orig,y_pred_orig,temp[0])
# Out:
# Bắt đầu với DỮ LIỆU GỐC
# ...
#
# Tỉ lệ: 80:20 (4:1)
# {'Tỉ lệ': '80:20 (4:1)', 'Dữ liệu': 'Dữ liệu gốc', 'Train R²': 0.822, 'Test R²': 0.8093, 'ΔR²': 0.0126, 'Train MSE': 16.0669, 'Test MSE': 17.2679, 'Overfit': 'Không'}
# [Train:Test = 80:20]
#   Mean residual  = -0.0543
#   Variance       = 17.2649
#   Std deviation  = 4.1551
# Tỉ lệ: 70:30 (7:3)
# {'Tỉ lệ': '70:30 (7:3)', 'Dữ liệu': 'Dữ liệu gốc', 'Train R²': 0.822, 'Test R²': 0.8126, 'ΔR²': 0.0095, 'Train MSE': 15.8402, 'Test MSE': 17.5262, 'Overfit': 'Không'}
# [Train:Test = 70:30]
#   Mean residual  = -0.0392
#   Variance       = 17.5247
#   Std deviation  = 4.1863
# Tỉ lệ: 60:40 (6:4)
# {'Tỉ lệ': '60:40 (6:4)', 'Dữ liệu': 'Dữ liệu gốc', 'Train R²': 0.8253, 'Test R²': 0.81, 'ΔR²': 0.0153, 'Train MSE': 15.8734, 'Test MSE': 17.0314, 'Overfit': 'Không'}
# [Train:Test = 60:40]
#   Mean residual  = 0.0647
#   Variance       = 17.0272
#   Std deviation  = 4.1264

# %% [markdown]
# ### 3.2.2. Hồi quy với dữ liệu giảm chiều

# %% [markdown]
# - Sử dụng X_pca (giảm từ ~20 xuống ~8-10 components, giữ 95% variance).
# - Kiến thức PCA ôn lại: PCA biến đổi tuyến tính dữ liệu thành orthogonal components, ưu tiên variance cao. Công thức: $X_{pca} = X \cdot W$, với $W$ là ma trận eigenvectors của covariance matrix $\Sigma = \frac{1}{n} X^T X$.
# - Công thức: Mô hình vẫn là linear trên components: $\hat{y} = \hat{\beta}_0 + \sum \hat{\beta}_i pc_i$.

# %%
print("\nBắt đầu với DỮ LIỆU PCA\n" + "="*50)

for train_size, test_size, ratio_name in split_ratios:
    print(f"\nTỉ lệ: {ratio_name}")
    
    X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(
        X, y, train_size=train_size,random_state=90
    )
    # Chuẩn hóa dữ liệu
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_pca)
    X_test_scaled = scaler.transform(X_test_pca)

    pca_full = PCA()
    pca_full.fit(X_train_scaled)
    cumvar = np.cumsum(pca_full.explained_variance_ratio_)
    n_comp = np.argmax(cumvar >= 0.95) + 1
    print(f"   Số components: {n_comp}")

    pca_95 = PCA(n_components=n_comp)
    X_train_pca_95 = pca_95.fit_transform(X_train_scaled)
    X_test_pca_95 = pca_95.transform(X_test_scaled)
    
    # Linear Regression
    lr_pca = LinearRegression()
    lr_pca.fit(X_train_pca_95, y_train_pca)
    y_pred_pca = []
    y_pred_pca = evaluate_lr(lr_pca, X_train_pca_95, X_test_pca_95, y_train_pca, y_test_pca, "Dữ liệu PCA", ratio_name)
    #Vẽ trục quan hóa
    temp = ratio_name.split()
    plot_residuals_single_split(y_test_pca,y_pred_pca,temp[0])
# Out:
# Bắt đầu với DỮ LIỆU PCA
# ...
#
# Tỉ lệ: 80:20 (4:1)
#    Số components: 15
# {'Tỉ lệ': '80:20 (4:1)', 'Dữ liệu': 'Dữ liệu PCA', 'Train R²': 0.8114, 'Test R²': 0.7993, 'ΔR²': 0.0121, 'Train MSE': 17.0236, 'Test MSE': 18.1756, 'Overfit': 'Không'}
# [Train:Test = 80:20]
#   Mean residual  = -0.0300
#   Variance       = 18.1747
#   Std deviation  = 4.2632
# Tỉ lệ: 70:30 (7:3)
#    Số components: 15
# {'Tỉ lệ': '70:30 (7:3)', 'Dữ liệu': 'Dữ liệu PCA', 'Train R²': 0.8112, 'Test R²': 0.8031, 'ΔR²': 0.0081, 'Train MSE': 16.8019, 'Test MSE': 18.4058, 'Overfit': 'Không'}
# [Train:Test = 70:30]
#   Mean residual  = -0.0311
#   Variance       = 18.4048
#   Std deviation  = 4.2901
# Tỉ lệ: 60:40 (6:4)
#    Số components: 15
# {'Tỉ lệ': '60:40 (6:4)', 'Dữ liệu': 'Dữ liệu PCA', 'Train R²': 0.8149, 'Test R²': 0.7997, 'ΔR²': 0.0151, 'Train MSE': 16.8195, 'Test MSE': 17.9531, 'Overfit': 'Không'}
# [Train:Test = 60:40]
#   Mean residual  = 0.1056
#   Variance       = 17.9419
#   Std deviation  = 4.2358

# %%
print("\nBắt đầu với DỮ LIỆU SelectKbest\n" + "="*50)

for train_size, test_size, ratio_name in split_ratios:
    print(f"\nTỉ lệ: {ratio_name}")
    
    X_train_skb, X_test_skb, y_train_skb, y_test_skb = train_test_split(
        X, y, train_size=train_size,random_state=90
    )
    # Chuẩn hóa dữ liệu
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_skb)
    X_test_scaled = scaler.transform(X_test_skb)

    skb = SelectKBest(score_func=f_regression, k=10)  
    X_train_best = skb.fit_transform(X_train_scaled, y_train_skb)
    X_test_best = skb.transform(X_test_scaled)

    selected_features = X.columns[skb.get_support()].tolist()
    print("Các đặc trưng được chọn:", selected_features)

    # Linear Regression
    lr_skb = LinearRegression()
    lr_skb.fit(X_train_best, y_train_skb)
    y_pred_skb = []
    y_pred_skb = evaluate_lr(lr_skb, X_train_best, X_test_best, y_train_skb, y_test_skb, "Dữ liệu Select KBest",ratio_name)
    print("="*50)

    #Vẽ trục quan hóa
    temp = ratio_name.split()
    plot_residuals_single_split(y_test_skb,y_pred_skb,temp[0])
# Out:
# Bắt đầu với DỮ LIỆU SelectKbest
# ...
#
# Tỉ lệ: 80:20 (4:1)
# Các đặc trưng được chọn: ['Adult Mortality', 'BMI', 'Polio', 'Diphtheria', 'HIV/AIDS', 'thinness  1-19 years', 'thinness 5-9 years', 'Income composition of resources', 'Schooling', 'Status_Developing']
# {'Tỉ lệ': '80:20 (4:1)', 'Dữ liệu': 'Dữ liệu Select KBest', 'Train R²': 0.8062, 'Test R²': 0.7985, 'ΔR²': 0.0077, 'Train MSE': 17.4916, 'Test MSE': 18.2484, 'Overfit': 'Không'}
# ...
# [Train:Test = 80:20]
#   Mean residual  = -0.0443
#   Variance       = 18.2464
#   Std deviation  = 4.2716
# Tỉ lệ: 70:30 (7:3)
# Các đặc trưng được chọn: ['Adult Mortality', 'BMI', 'Polio', 'Diphtheria', 'HIV/AIDS', 'thinness  1-19 years', 'thinness 5-9 years', 'Income composition of resources', 'Schooling', 'Status_Developing']
# {'Tỉ lệ': '70:30 (7:3)', 'Dữ liệu': 'Dữ liệu Select KBest', 'Train R²': 0.8057, 'Test R²': 0.8017, 'ΔR²': 0.004, 'Train MSE': 17.2939, 'Test MSE': 18.539, 'Overfit': 'Không'}
# ...
# [Train:Test = 70:30]
# ...

# %% [markdown]
# ### So sánh, nhận xét và đánh giá kết quả

# %%
# Tạo bảng kết quả
results_df = pd.DataFrame(results)
display(results_df)
# Out:
#          Tỉ lệ               Dữ liệu  Train R²  Test R²     ΔR²  Train MSE  \
# 0  80:20 (4:1)           Dữ liệu gốc    0.8220   0.8093  0.0126    16.0669
# 1  70:30 (7:3)           Dữ liệu gốc    0.8220   0.8126  0.0095    15.8402
# 2  60:40 (6:4)           Dữ liệu gốc    0.8253   0.8100  0.0153    15.8734
# 3  80:20 (4:1)           Dữ liệu PCA    0.8114   0.7993  0.0121    17.0236
# 4  70:30 (7:3)           Dữ liệu PCA    0.8112   0.8031  0.0081    16.8019
# 5  60:40 (6:4)           Dữ liệu PCA    0.8149   0.7997  0.0151    16.8195
# 6  80:20 (4:1)  Dữ liệu Select KBest    0.8062   0.7985  0.0077    17.4916
# 7  70:30 (7:3)  Dữ liệu Select KBest    0.8057   0.8017  0.0040    17.2939
# 8  60:40 (6:4)  Dữ liệu Select KBest    0.8090   0.7979  0.0111    17.3492
#
#    Test MSE Overfit
# 0   17.2679   Không
# 1   17.5262   Không
# 2   17.0314   Không
# 3   18.1756   Không
# 4   18.4058   Không
# 5   17.9531   Không
# 6   18.2484   Không
# 7   18.5390   Không
# 8   18.1168   Không

# %%
plt.figure(figsize=(14, 8))

# Biểu đồ R² theo tỉ lệ
sns.set_style("whitegrid")
results_plot = results_df[results_df['Dữ liệu'].str.contains('gốc|PCA|Select KBest') & ~results_df['Dữ liệu'].str.contains('Ridge|Lasso')]

sns.lineplot(data=results_plot, x='Tỉ lệ', y='Test R²', hue='Dữ liệu', marker='o', linewidth=2.5)
plt.title('So sánh Test R² theo tỉ lệ chia dữ liệu', fontsize=16)
plt.ylabel('Test R²')
plt.xlabel('Tỉ lệ Train:Validation')
plt.legend(title='Dữ liệu')
plt.tight_layout()
plt.show()

# %%
# Biểu đồ ΔR² theo tỉ lệ
plt.figure(figsize=(10, 6))
sns.barplot(data=results_df, x='Tỉ lệ', y='ΔR²', hue='Dữ liệu', palette='husl')
plt.axhline(0.05, color='red', linestyle='--', label='Ngưỡng overfit')
plt.title('So sánh độ chênh lệch R² (ΔR²) theo tỉ lệ chia')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Lọc dữ liệu
df_orig_lr = results_df[results_df['Dữ liệu'].str.contains('gốc')]
df_pca_lr  = results_df[results_df['Dữ liệu'].str.contains('PCA')]
df_skb_lr  = results_df[results_df['Dữ liệu'].str.contains('Select KBest')]

# Tính trung bình ΔR²
mean_orig_lr = df_orig_lr['ΔR²'].mean()
mean_pca_lr  = df_pca_lr['ΔR²'].mean()
mean_skb_lr  = df_skb_lr['ΔR²'].mean()

print(f"ΔR² trung bình (dữ liệu gốc): {mean_orig_lr:.4f}")
print(f"ΔR² trung bình (dữ liệu PCA):  {mean_pca_lr:.4f}")
print(f"ΔR² trung bình (dữ liệu Select KBest):  {mean_skb_lr:.4f}")
print(f"PCA giúp giảm ΔR²: {((mean_orig_lr - mean_pca_lr)/mean_orig_lr*100):.1f}%")
print(f"Select KBest giúp giảm ΔR²: {((mean_orig_lr - mean_skb_lr)/mean_orig_lr*100):.1f}%")
# Out:
# ΔR² trung bình (dữ liệu gốc): 0.0125
# ΔR² trung bình (dữ liệu PCA):  0.0118
# ΔR² trung bình (dữ liệu Select KBest):  0.0076
# PCA giúp giảm ΔR²: 5.6%
# Select KBest giúp giảm ΔR²: 39.0%

# %% [markdown]
# Nhận xét:
# - Dữ liệu gốc luôn cho Test R² cao hơn PCA
# - Tỉ lệ 7:3 là tốt nhất
# -Tỉ lệ 7:3 là tối ưu – Test R² cao nhất, ΔR² thấp nhất
# - Không có overfit ở bất kỳ trường hợp nào
# - ΔR² < 0.05 → mô hình tổng quát hóa tốt

# %% [markdown]
# # Phần 4: PHÂN CỤM DỮ LIỆU (K-MEANS & GMM)

# %%
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from scipy.stats import f_oneway
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import os

# %% [markdown]
# ## 4.1.Chuẩn bị dữ liệu cho phân cụm

# %%
print("\n[1] Chuẩn bị dữ liệu cho phân cụm...")

X_cluster = X.copy()  
y_cluster = y.copy()  

print(f"Kích thước dữ liệu phân cụm: {X_cluster.shape}")
print(f"Số features: {X_cluster.shape[1]}")

# Chuẩn hóa dữ liệu
scaler_cluster = StandardScaler()
X_scaled_cluster = scaler_cluster.fit_transform(X_cluster)
print(f"Đã chuẩn hóa dữ liệu (mean ≈ 0, std ≈ 1)")
# Out:
# [1] Chuẩn bị dữ liệu cho phân cụm...
# Kích thước dữ liệu phân cụm: (2938, 20)
# Số features: 20
# Đã chuẩn hóa dữ liệu (mean ≈ 0, std ≈ 1)

# %% [markdown]
# ## 4.2. Xác định số cụm tối ưu

# %%
print("\n[2] Xác định số cụm tối ưu...")

K_range = range(2, 11)
metrics_results = {
    'K': [],
    'Inertia': [],
    'Silhouette (K-Means)': [],
    'Davies-Bouldin (K-Means)': [],
    'Calinski-Harabasz (K-Means)': [],
    'BIC (GMM)': [],
    'AIC (GMM)': [],
    'Silhouette (GMM)': []
}

print(f"Thử nghiệm với K từ {min(K_range)} đến {max(K_range)}...")

for k in K_range:
    # K-Means
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels_km = kmeans.fit_predict(X_scaled_cluster)
    
    # GMM
    gmm = GaussianMixture(n_components=k, random_state=42)
    labels_gmm = gmm.fit_predict(X_scaled_cluster)
    
    # Tính các metrics
    metrics_results['K'].append(k)
    metrics_results['Inertia'].append(kmeans.inertia_)
    metrics_results['Silhouette (K-Means)'].append(silhouette_score(X_scaled_cluster, labels_km))
    metrics_results['Davies-Bouldin (K-Means)'].append(davies_bouldin_score(X_scaled_cluster, labels_km))
    metrics_results['Calinski-Harabasz (K-Means)'].append(calinski_harabasz_score(X_scaled_cluster, labels_km))
    metrics_results['BIC (GMM)'].append(gmm.bic(X_scaled_cluster))
    metrics_results['AIC (GMM)'].append(gmm.aic(X_scaled_cluster))
    metrics_results['Silhouette (GMM)'].append(silhouette_score(X_scaled_cluster, labels_gmm))

metrics_df = pd.DataFrame(metrics_results)

# Vẽ biểu đồ so sánh các metrics
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

axes[0, 0].plot(metrics_df['K'], metrics_df['Inertia'], 'bo-', linewidth=2, markersize=8)
axes[0, 0].set_title('Elbow Method (Inertia)', fontsize=12, fontweight='bold')
axes[0, 0].set_xlabel('Số cụm K', fontsize=10)
axes[0, 0].set_ylabel('Inertia', fontsize=10)
axes[0, 0].grid(alpha=0.3)

axes[0, 1].plot(metrics_df['K'], metrics_df['Silhouette (K-Means)'], 'go-', linewidth=2, markersize=8)
axes[0, 1].set_title('Silhouette Score (K-Means)', fontsize=12, fontweight='bold')
axes[0, 1].set_xlabel('Số cụm K', fontsize=10)
axes[0, 1].set_ylabel('Silhouette Score', fontsize=10)
axes[0, 1].grid(alpha=0.3)

axes[0, 2].plot(metrics_df['K'], metrics_df['Davies-Bouldin (K-Means)'], 'ro-', linewidth=2, markersize=8)
axes[0, 2].set_title('Davies-Bouldin Index (Thấp tốt)', fontsize=12, fontweight='bold')
axes[0, 2].set_xlabel('Số cụm K', fontsize=10)
axes[0, 2].set_ylabel('DB Index', fontsize=10)
axes[0, 2].grid(alpha=0.3)

axes[1, 0].plot(metrics_df['K'], metrics_df['BIC (GMM)'], 'bs-', label='BIC', linewidth=2, markersize=8)
axes[1, 0].plot(metrics_df['K'], metrics_df['AIC (GMM)'], 'g^-', label='AIC', linewidth=2, markersize=8)
axes[1, 0].set_title('BIC & AIC (GMM - Thấp tốt)', fontsize=12, fontweight='bold')
axes[1, 0].set_xlabel('Số cụm K', fontsize=10)
axes[1, 0].set_ylabel('BIC/AIC', fontsize=10)
axes[1, 0].legend(fontsize=10)
axes[1, 0].grid(alpha=0.3)

axes[1, 1].plot(metrics_df['K'], metrics_df['Silhouette (GMM)'], 'mo-', linewidth=2, markersize=8)
axes[1, 1].set_title('Silhouette Score (GMM)', fontsize=12, fontweight='bold')
axes[1, 1].set_xlabel('Số cụm K', fontsize=10)
axes[1, 1].set_ylabel('Silhouette Score', fontsize=10)
axes[1, 1].grid(alpha=0.3)

axes[1, 2].plot(metrics_df['K'], metrics_df['Calinski-Harabasz (K-Means)'], 'co-', linewidth=2, markersize=8)
axes[1, 2].set_title('Calinski-Harabasz (Cao tốt)', fontsize=12, fontweight='bold')
axes[1, 2].set_xlabel('Số cụm K', fontsize=10)
axes[1, 2].set_ylabel('CH Score', fontsize=10)
axes[1, 2].grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# [2] Xác định số cụm tối ưu...
# Thử nghiệm với K từ 2 đến 10...

# %%
# Lý do chọn K=3
print("\nPhân tích lựa chọn số cụm tối ưu:")
print("-" * 70)
print("Dựa trên các chỉ số đánh giá:")

# Tìm chính xác hàng tương ứng với K=3
k3_row = metrics_df[metrics_df['K'] == 3].iloc[0]

print(f" - K=3 có Silhouette Score tốt cho cả K-Means ({k3_row['Silhouette (K-Means)']:.4f}) "
      f"và GMM ({k3_row['Silhouette (GMM)']:.4f})")
print(f" - Davies-Bouldin Index thấp (K-Means: {k3_row['Davies-Bouldin (K-Means)']:.4f}), "
      f"cho thấy các cụm phân tách tốt")
print(f" - Calinski-Harabasz Score cao ({k3_row['Calinski-Harabasz (K-Means)']:.2f}), "
      f"các cụm compact và tách biệt")
print(f" - BIC và AIC của GMM đạt giá trị tốt ở K=3 "
      f"(BIC = {k3_row['BIC (GMM)']:.2f}, AIC = {k3_row['AIC (GMM)']:.2f})")
print(f" - Elbow Method cho thấy điểm khuỷu tay rõ ràng tại K=3")

print(f"\nKẾT LUẬN: Chọn K = 3 làm số cụm tối ưu")
# Out:
# Phân tích lựa chọn số cụm tối ưu:
# ----------------------------------------------------------------------
# Dựa trên các chỉ số đánh giá:
#  - K=3 có Silhouette Score tốt cho cả K-Means (0.2198) và GMM (0.1529)
#  - Davies-Bouldin Index thấp (K-Means: 1.4455), cho thấy các cụm phân tách tốt
#  - Calinski-Harabasz Score cao (610.38), các cụm compact và tách biệt
#  - BIC và AIC của GMM đạt giá trị tốt ở K=3 (BIC = 38804.72, AIC = 34662.77)
#  - Elbow Method cho thấy điểm khuỷu tay rõ ràng tại K=3
#
# KẾT LUẬN: Chọn K = 3 làm số cụm tối ưu

# %% [markdown]
# ## 4.3.Áp dụng K-Means và GMM với K=3

# %%
print("\n[3] Áp dụng K-Means và GMM với K=3...")
optimal_k = 3

# K-Means
kmeans_final = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
labels_kmeans = kmeans_final.fit_predict(X_scaled_cluster)

# GMM
gmm_final = GaussianMixture(n_components=optimal_k, random_state=42, n_init=10)
labels_gmm = gmm_final.fit_predict(X_scaled_cluster)

# Tính metrics cuối cùng
sil_km = silhouette_score(X_scaled_cluster, labels_kmeans)
sil_gmm = silhouette_score(X_scaled_cluster, labels_gmm)
db_km = davies_bouldin_score(X_scaled_cluster, labels_kmeans)
db_gmm = davies_bouldin_score(X_scaled_cluster, labels_gmm)
ch_km = calinski_harabasz_score(X_scaled_cluster, labels_kmeans)
ch_gmm = calinski_harabasz_score(X_scaled_cluster, labels_gmm)

print(f"\nKết quả đánh giá chất lượng phân cụm:")
print(f"+-----------------------------------------------+")
print(f"| K-Means Results:                              |")
print(f"|   Silhouette Score:      {sil_km:>6.4f}          |")
print(f"|   Davies-Bouldin Index:  {db_km:>6.4f}          |")
print(f"|   Calinski-Harabasz:     {ch_km:>8.2f}        |")
print(f"+-----------------------------------------------+")
print(f"| GMM Results:                                  |")
print(f"|   Silhouette Score:      {sil_gmm:>6.4f}          |")
print(f"|   Davies-Bouldin Index:  {db_gmm:>6.4f}          |")
print(f"|   Calinski-Harabasz:     {ch_gmm:>8.2f}        |")
print(f"+-----------------------------------------------+")
# Out:
# [3] Áp dụng K-Means và GMM với K=3...
#
# Kết quả đánh giá chất lượng phân cụm:
# +-----------------------------------------------+
# | K-Means Results:                              |
# |   Silhouette Score:      0.2198          |
# |   Davies-Bouldin Index:  1.4455          |
# |   Calinski-Harabasz:       610.38        |
# +-----------------------------------------------+
# | GMM Results:                                  |
# |   Silhouette Score:      0.0864          |
# |   Davies-Bouldin Index:  2.4430          |
# |   Calinski-Harabasz:       382.10        |
# +-----------------------------------------------+

# %% [markdown]
# ## 4.4.Phân tích quan hệ giữa các cụm và Life Expectancy (Đầu ra)

# %%
print("\n[4] Phân tích quan hệ giữa các cụm và Life Expectancy...")

df_cluster_analysis = pd.DataFrame({
    'Life_expectancy': y_cluster.values,
    'Cluster_KMeans': labels_kmeans,
    'Cluster_GMM': labels_gmm
})

# Thống kê mô tả
print("\nK-Means - Thống kê Life Expectancy theo cụm:")
stats_km = df_cluster_analysis.groupby('Cluster_KMeans')['Life_expectancy'].describe()
print(stats_km[['count', 'mean', 'std', 'min', 'max']])

print("\nGMM - Thống kê Life Expectancy theo cụm:")
stats_gmm = df_cluster_analysis.groupby('Cluster_GMM')['Life_expectancy'].describe()
print(stats_gmm[['count', 'mean', 'std', 'min', 'max']])

# Vẽ boxplot
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.boxplot(x='Cluster_KMeans', y='Life_expectancy', data=df_cluster_analysis, 
            ax=axes[0], palette='Blues')
axes[0].set_title('K-Means: Phân bố Life Expectancy theo cụm', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Cụm', fontsize=10)
axes[0].set_ylabel('Life Expectancy (năm)', fontsize=10)
axes[0].grid(alpha=0.3, axis='y')

sns.boxplot(x='Cluster_GMM', y='Life_expectancy', data=df_cluster_analysis, 
            ax=axes[1], palette='Reds')
axes[1].set_title('GMM: Phân bố Life Expectancy theo cụm', fontsize=12, fontweight='bold')
axes[1].set_xlabel('Cụm', fontsize=10)
axes[1].set_ylabel('Life Expectancy (năm)', fontsize=10)
axes[1].grid(alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

# Kiểm định ANOVA
print("\nKIỂM ĐỊNH ANOVA (Đánh giá quan hệ giữa phân cụm và đầu ra):")
print("-" * 70)

# ANOVA cho K-Means
groups_km = [df_cluster_analysis[df_cluster_analysis['Cluster_KMeans']==i]['Life_expectancy'] 
             for i in range(optimal_k)]
f_stat_km, p_value_km = f_oneway(*groups_km)

print(f"K-Means:")
print(f"  F-statistic: {f_stat_km:.2f}")
print(f"  P-value: {p_value_km:.4e}")
if p_value_km < 0.05:
    print(f"  Kết luận: Có sự khác biệt CÓ Ý NGHĨA THỐNG KÊ về Life Expectancy")
    print(f"            giữa các cụm (P-value < 0.05)")
else:
    print(f"  Kết luận: Không có sự khác biệt có ý nghĩa thống kê (P-value >= 0.05)")

# ANOVA cho GMM
groups_gmm = [df_cluster_analysis[df_cluster_analysis['Cluster_GMM']==i]['Life_expectancy'] 
              for i in range(optimal_k)]
f_stat_gmm, p_value_gmm = f_oneway(*groups_gmm)

print(f"\nGMM:")
print(f"  F-statistic: {f_stat_gmm:.2f}")
print(f"  P-value: {p_value_gmm:.4e}")
if p_value_gmm < 0.05:
    print(f"  Kết luận: Có sự khác biệt CÓ Ý NGHĨA THỐNG KÊ về Life Expectancy")
    print(f"            giữa các cụm (P-value < 0.05)")
else:
    print(f"  Kết luận: Không có sự khác biệt có ý nghĩa thống kê (P-value >= 0.05)")
# Out:
# [4] Phân tích quan hệ giữa các cụm và Life Expectancy...
#
# K-Means - Thống kê Life Expectancy theo cụm:
#                  count       mean       std   min   max
# Cluster_KMeans
# 0               1226.0  61.055812  8.124382  36.3  79.0
# 1               1692.0  75.230452  4.845094  59.2  89.0
# 2                 20.0  61.925000  7.367702  47.1  68.3
#
# GMM - Thống kê Life Expectancy theo cụm:
#               count       mean       std   min   max
# Cluster_GMM
# 0             877.0  59.597834  8.467951  36.3  81.7
# 1             761.0  78.108541  4.318938  62.8  89.0
# 2            1300.0  70.519192  5.884688  49.2  89.0
# KIỂM ĐỊNH ANOVA (Đánh giá quan hệ giữa phân cụm và đầu ra):
# ----------------------------------------------------------------------
# K-Means:
#   F-statistic: 1736.92
#   P-value: 0.0000e+00
#   Kết luận: Có sự khác biệt CÓ Ý NGHĨA THỐNG KÊ về Life Expectancy
#             giữa các cụm (P-value < 0.05)
#
# GMM:
#   F-statistic: 1726.66
# ...

# %% [markdown]
# ## 4.5.Trực quan hóa dữ liệu bằng PCA 2D

# %%
print("\n[5] Trực quan hóa dữ liệu phân cụm bằng PCA 2D...")

pca_2d = PCA(n_components=2, random_state=42)
X_pca_2d = pca_2d.fit_transform(X_scaled_cluster)
centroids_pca = pca_2d.transform(kmeans_final.cluster_centers_)
centroids_gmm_pca = pca_2d.transform(gmm_final.means_)

print(f"Giải thích phương sai: PC1={pca_2d.explained_variance_ratio_[0]:.2%}, "
      f"PC2={pca_2d.explained_variance_ratio_[1]:.2%}")

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# K-Means Plot
scatter1 = axes[0].scatter(X_pca_2d[:, 0], X_pca_2d[:, 1], c=labels_kmeans, 
                          cmap='viridis', alpha=0.6, s=20, edgecolors='black', linewidth=0.3)
axes[0].scatter(centroids_pca[:, 0], centroids_pca[:, 1], c='red', marker='X', 
               s=300, edgecolor='black', linewidth=2, label='Centroids', zorder=10)
axes[0].set_title(f'K-Means (K={optimal_k}) - PCA 2D', fontsize=12, fontweight='bold')
axes[0].set_xlabel(f'PC1 ({pca_2d.explained_variance_ratio_[0]:.1%})', fontsize=10)
axes[0].set_ylabel(f'PC2 ({pca_2d.explained_variance_ratio_[1]:.1%})', fontsize=10)
axes[0].legend(fontsize=10)
axes[0].grid(alpha=0.3)
plt.colorbar(scatter1, ax=axes[0], label='Cluster')

# GMM Plot
scatter2 = axes[1].scatter(X_pca_2d[:, 0], X_pca_2d[:, 1], c=labels_gmm, 
                          cmap='plasma', alpha=0.6, s=20, edgecolors='black', linewidth=0.3)
axes[1].scatter(centroids_gmm_pca[:, 0], centroids_gmm_pca[:, 1], c='red', marker='X', 
               s=300, edgecolor='black', linewidth=2, label='Means', zorder=10)
axes[1].set_title(f'GMM (K={optimal_k}) - PCA 2D', fontsize=12, fontweight='bold')
axes[1].set_xlabel(f'PC1 ({pca_2d.explained_variance_ratio_[0]:.1%})', fontsize=10)
axes[1].set_ylabel(f'PC2 ({pca_2d.explained_variance_ratio_[1]:.1%})', fontsize=10)
axes[1].legend(fontsize=10)
axes[1].grid(alpha=0.3)
plt.colorbar(scatter2, ax=axes[1], label='Cluster')

plt.tight_layout()
plt.show()
# Out:
# [5] Trực quan hóa dữ liệu phân cụm bằng PCA 2D...
# Giải thích phương sai: PC1=29.40%, PC2=13.28%

# %% [markdown]
# ## 4.6.Phân tích đặc trưng của các cụm (Đầu vào)

# %%
print("\n[6] Phân tích đặc trưng trung bình của các cụm...")

df_features_cluster = pd.DataFrame(X_cluster, columns=X.columns)
df_features_cluster['Cluster_KMeans'] = labels_kmeans

# Chọn features quan trọng
important_cols = ['Adult Mortality', 'BMI', 'HIV/AIDS', 'Income composition of resources', 
                  'Schooling', 'GDP']
valid_cols = [c for c in important_cols if c in df_features_cluster.columns]

cluster_means = df_features_cluster.groupby('Cluster_KMeans')[valid_cols].mean()

# Chuẩn hóa Z-score
means_global = df_features_cluster[valid_cols].mean()
std_global = df_features_cluster[valid_cols].std()
cluster_means_norm = (cluster_means - means_global) / std_global

# Vẽ Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(cluster_means_norm.T, annot=True, fmt='.2f', cmap='RdBu_r', center=0,
            cbar_kws={'label': 'Z-score'}, linewidths=0.5)
plt.title('Heatmap: Đặc trưng các cụm so với trung bình chung (Z-score)', 
          fontsize=12, fontweight='bold')
plt.xlabel('Cluster (K-Means)', fontsize=10)
plt.ylabel('Features', fontsize=10)
plt.tight_layout()
plt.show()

# Nhận xét đặc điểm các cụm
print("\nNHẬN XÉT ĐẶC ĐIỂM CÁC CỤM:")
print("=" * 70)
for i in range(optimal_k):
    print(f"\nCụm {i}:")
    row = cluster_means_norm.loc[i]
    high = row[row > 0.5].index.tolist()
    low = row[row < -0.5].index.tolist()
    
    if high: 
        print(f"   Đặc điểm CAO: {', '.join(high)}")
    if low:  
        print(f"   Đặc điểm THẤP: {', '.join(low)}")
    
    life_mean = stats_km.loc[i, 'mean']
    life_std = stats_km.loc[i, 'std']
    count = int(stats_km.loc[i, 'count'])
    print(f"   Life Expectancy: {life_mean:.1f} +/- {life_std:.1f} năm ({count} mẫu)")
# Out:
# [6] Phân tích đặc trưng trung bình của các cụm...
# NHẬN XÉT ĐẶC ĐIỂM CÁC CỤM:
# ...
#
# Cụm 0:
#    Đặc điểm CAO: Adult Mortality
#    Đặc điểm THẤP: BMI, Income composition of resources, Schooling
#    Life Expectancy: 61.1 +/- 8.1 năm (1226 mẫu)
#
# Cụm 1:
#    Đặc điểm CAO: BMI, Income composition of resources, Schooling
#    Life Expectancy: 75.2 +/- 4.8 năm (1692 mẫu)
#
# Cụm 2:
#    Đặc điểm THẤP: BMI, Income composition of resources, Schooling, GDP
#    Life Expectancy: 61.9 +/- 7.4 năm (20 mẫu)

# %% [markdown]
# # Phần 5: Chuyển bài toán hồi quy sang phân loại

# %%
print("\n" + "="*80)
print("PHẦN 5: TẠO NHÃN PHÂN LOẠI DỰA TRÊN KẾT QUẢ PHÂN CỤM")
print("="*80)
# Out:
# ...
# PHẦN 5: TẠO NHÃN PHÂN LOẠI DỰA TRÊN KẾT QUẢ PHÂN CỤM
# ...

# %% [markdown]
# ## 5.1. Chuẩn bị dữ liệu

# %% [markdown]
# ### 5.1.1. Kết quả phân cụm

# %%
cluster_life_kmeans = []
for i in range(optimal_k):
    mean_val = stats_km.loc[i, 'mean']
    count_val = int(stats_km.loc[i, 'count'])
    cluster_life_kmeans.append((i, mean_val, count_val))

cluster_life_kmeans_sorted = sorted(cluster_life_kmeans, key=lambda x: x[1])

print("\nCác cụm Kmeans được sắp xếp theo Life Expectancy:")
for idx, (cluster_id, mean_val, count_val) in enumerate(cluster_life_kmeans_sorted):
    print(f"  Cụm {cluster_id}: Mean = {mean_val:.2f} năm ({count_val} mẫu)")

cluster_life_means = []
for i in range(optimal_k):
    mean_val = stats_gmm.loc[i, 'mean']
    count_val = int(stats_gmm.loc[i, 'count'])
    cluster_life_means.append((i, mean_val, count_val))

cluster_life_means_sorted = sorted(cluster_life_means, key=lambda x: x[1])

print("\nCác cụm GMM được sắp xếp theo Life Expectancy:")
for idx, (cluster_id, mean_val, count_val) in enumerate(cluster_life_means_sorted):
    print(f"  Cụm {cluster_id}: Mean = {mean_val:.2f} năm ({count_val} mẫu)")
# Out:
# Các cụm Kmeans được sắp xếp theo Life Expectancy:
#   Cụm 0: Mean = 61.06 năm (1226 mẫu)
#   Cụm 2: Mean = 61.92 năm (20 mẫu)
#   Cụm 1: Mean = 75.23 năm (1692 mẫu)
#
# Các cụm GMM được sắp xếp theo Life Expectancy:
#   Cụm 0: Mean = 59.60 năm (877 mẫu)
#   Cụm 2: Mean = 70.52 năm (1300 mẫu)
#   Cụm 1: Mean = 78.11 năm (761 mẫu)

# %% [markdown]
# *Nhận xét*: GMM phân ra 3 cụm có mean tuổi thọ phân khá rõ ràng và số lượng mẫu ở mỗi cụm không quá mất cân bằng như Kmeans. Nhóm sẽ chọn kết quả phân cụm của GMM để điều chỉnh và chia đầu ra thành 3 nhóm xấp xỉ nhau.

# %% [markdown]
# ### 5.1.2. Phân tích kết quả phân cụm từ GMM

# %%
print("\n[Bước 1] Phân tích Life Expectancy theo các cụm GMM...")

# Sắp xếp các cụm theo mean Life Expectancy
cluster_life_means = []
for i in range(optimal_k):
    mean_val = stats_gmm.loc[i, 'mean']
    count_val = int(stats_gmm.loc[i, 'count'])
    cluster_life_means.append((i, mean_val, count_val))

cluster_life_means_sorted = sorted(cluster_life_means, key=lambda x: x[1])

print("\nCác cụm GMM được sắp xếp theo Life Expectancy:")
for idx, (cluster_id, mean_val, count_val) in enumerate(cluster_life_means_sorted):
    print(f"  Cụm {cluster_id}: Mean = {mean_val:.2f} năm ({count_val} mẫu)")

# Gán ý nghĩa: Thấp, Trung bình, Cao
mean_low = cluster_life_means_sorted[0][1]
mean_mid = cluster_life_means_sorted[1][1]
mean_high = cluster_life_means_sorted[2][1]

print(f"\nCác giá trị trung bình từ GMM:")
print(f"   Nhóm Thấp:       {mean_low:.2f} năm")
print(f"   Nhóm Trung bình: {mean_mid:.2f} năm")
print(f"   Nhóm Cao:        {mean_high:.2f} năm")
# Out:
# [Bước 1] Phân tích Life Expectancy theo các cụm GMM...
#
# Các cụm GMM được sắp xếp theo Life Expectancy:
#   Cụm 0: Mean = 59.60 năm (877 mẫu)
#   Cụm 2: Mean = 70.52 năm (1300 mẫu)
#   Cụm 1: Mean = 78.11 năm (761 mẫu)
#
# Các giá trị trung bình từ GMM:
#    Nhóm Thấp:       59.60 năm
#    Nhóm Trung bình: 70.52 năm
#    Nhóm Cao:        78.11 năm

# %% [markdown]
# ### 5.1.3. Tính ngưỡng dựa trên midpoint giữa các mean

# %%
print("\n[Bước 2] Tính ngưỡng gợi ý từ kết quả phân cụm...")

threshold_suggest_1 = (mean_low + mean_mid) / 2
threshold_suggest_2 = (mean_mid + mean_high) / 2

print(f"   Ngưỡng gợi ý 1 (Thấp/Trung bình): {threshold_suggest_1:.2f}")
print(f"   Ngưỡng gợi ý 2 (Trung bình/Cao):  {threshold_suggest_2:.2f}")
# Out:
# [Bước 2] Tính ngưỡng gợi ý từ kết quả phân cụm...
#    Ngưỡng gợi ý 1 (Thấp/Trung bình): 65.06
#    Ngưỡng gợi ý 2 (Trung bình/Cao):  74.31

# %% [markdown]
# ### 5.1.4. Tinh chỉnh ngưỡng để cân bằng số lượng mẫu

# %%
print("\n[Bước 3] Tinh chỉnh ngưỡng để cân bằng số lượng mẫu...")

total_samples = len(y_cluster)
target_per_group = total_samples // 3
print(f"   Tổng số mẫu: {total_samples}")
print(f"   Mục tiêu mỗi nhóm: ~{target_per_group} mẫu")

# Tìm ngưỡng 1
best_threshold_1 = None
best_diff_1 = float('inf')
search_range_1 = np.arange(threshold_suggest_1 - 3, threshold_suggest_1 + 3, 0.1)

for t in search_range_1:
    t = round(t, 1)
    count_low = (y_cluster < t).sum()
    diff = abs(count_low - target_per_group)
    if diff < best_diff_1:
        best_diff_1 = diff
        best_threshold_1 = t

# Tìm ngưỡng 2
best_threshold_2 = None
best_diff_2 = float('inf')
search_range_2 = np.arange(threshold_suggest_2 - 3, threshold_suggest_2 + 3, 0.1)

for t in search_range_2:
    t = round(t, 1)
    count_mid = ((y_cluster >= best_threshold_1) & (y_cluster < t)).sum()
    diff = abs(count_mid - target_per_group)
    if diff < best_diff_2:
        best_diff_2 = diff
        best_threshold_2 = t

final_threshold_1 = best_threshold_1
final_threshold_2 = best_threshold_2

print(f"\nNgưỡng sau khi tinh chỉnh:")
print(f"   Threshold 1: {final_threshold_1:.1f} (lệch {best_diff_1} mẫu so với mục tiêu)")
print(f"   Threshold 2: {final_threshold_2:.1f} (lệch {best_diff_2} mẫu so với mục tiêu)")
# Out:
# [Bước 3] Tinh chỉnh ngưỡng để cân bằng số lượng mẫu...
#    Tổng số mẫu: 2938
#    Mục tiêu mỗi nhóm: ~979 mẫu
#
# Ngưỡng sau khi tinh chỉnh:
#    Threshold 1: 66.6 (lệch 5 mẫu so với mục tiêu)
#    Threshold 2: 74.4 (lệch 4 mẫu so với mục tiêu)

# %% [markdown]
# ### 5.1.5. Tạo nhãn phân loại

# %%
print("\n[Bước 4] Tạo nhãn phân loại...")

def assign_classification_label(val):
    if val < final_threshold_1:
        return 0  # Thấp
    elif val < final_threshold_2:
        return 1  # Trung bình
    else:
        return 2  # Cao

classification_labels = y_cluster.apply(assign_classification_label)
label_names = ['Thấp', 'Trung bình', 'Cao']

print(f"\nKhoảng giá trị cho mỗi nhãn:")
print(f"   Nhóm 0 (Thấp):       Life expectancy < {final_threshold_1:.1f}")
print(f"   Nhóm 1 (Trung bình): {final_threshold_1:.1f} <= Life expectancy < {final_threshold_2:.1f}")
print(f"   Nhóm 2 (Cao):        Life expectancy >= {final_threshold_2:.1f}")

# Kiểm tra phân bố
label_counts = pd.Series(classification_labels).value_counts().sort_index()

print("\nPhân bố số lượng mẫu theo nhãn:")
print("+--------+-------------+------------+--------------------------+")
print("| Nhãn   | Tên nhóm    | Số mẫu     | Tỷ lệ                    |")
print("+--------+-------------+------------+--------------------------+")
for label in range(3):
    count = label_counts[label]
    pct = count / total_samples * 100
    bar = '#' * int(pct / 2)
    print(f"|   {label}    | {label_names[label]:<11} | {count:>6}     | {pct:>5.1f}% {bar:<20} |")
print("+--------+-------------+------------+--------------------------+")
# Out:
# [Bước 4] Tạo nhãn phân loại...
#
# Khoảng giá trị cho mỗi nhãn:
#    Nhóm 0 (Thấp):       Life expectancy < 66.6
#    Nhóm 1 (Trung bình): 66.6 <= Life expectancy < 74.4
#    Nhóm 2 (Cao):        Life expectancy >= 74.4
#
# Phân bố số lượng mẫu theo nhãn:
# +--------+-------------+------------+--------------------------+
# | Nhãn   | Tên nhóm    | Số mẫu     | Tỷ lệ                    |
# +--------+-------------+------------+--------------------------+
# |   0    | Thấp        |    974     |  33.2% ################     |
# |   1    | Trung bình  |    975     |  33.2% ################     |
# |   2    | Cao         |    989     |  33.7% ################     |
# +--------+-------------+------------+--------------------------+

# %% [markdown]
# ## 5.2. Các mô hình phân loại

# %% [markdown]
# ### 5.2.1. Kiểm tra dữ liệu

# %%
X_classifier = X.copy()
y_classifier = classification_labels.copy()
print("Kiểm tra dữ liệu đầu vào:")
print(f"X_classifier shape: {X_classifier.shape}")
print(f"y_classifier shape: {y_classifier.shape}")
print(f"Phân bố nhãn:\n{pd.Series(y_classifier).value_counts().sort_index()}")
# Out:
# Kiểm tra dữ liệu đầu vào:
# X_classifier shape: (2938, 20)
# y_classifier shape: (2938,)
# Phân bố nhãn:
# Life expectancy
# 0    974
# 1    975
# 2    989
# Name: count, dtype: int64

# %% [markdown]
# ### 5.2.2. Chuẩn bị các tỉ lệ chia

# %%
# Các tỷ lệ chia train/test
ratios = [
    {"name": "4:1 (80/20)", "test_size": 0.2},
    {"name": "7:3 (70/30)", "test_size": 0.3},
    {"name": "6:4 (60/40)", "test_size": 0.4}
]

print("Sẵn sàng huấn luyện mô hình")
# Out:
# Sẵn sàng huấn luyện mô hình

# %% [markdown]
# ### 5.2.3. Huấn luyện và đánh giá mô hình

# %%
# Hàm huấn luyện và đánh giá mô hình
def evaluate_model(model, X_train, X_test, y_train, y_test, data_type, ratio_name):
    # Huấn luyện
    model.fit(X_train, y_train)
    
    # Dự đoán
    y_pred_train = model.predict(X_train)
    y_pred_test  = model.predict(X_test)
    
    # Đánh giá
    train_acc = accuracy_score(y_train, y_pred_train)
    val_acc = accuracy_score(y_test,  y_pred_test)
    diff = train_acc - val_acc
    clf_report = classification_report(y_test, y_pred_test, target_names=label_names, zero_division=0)
    recall = recall_score(y_test, y_pred_test, average='macro', zero_division=0)
    f1 = f1_score(y_test, y_pred_test, average='macro', zero_division=0)
    cm = confusion_matrix(y_test, y_pred_test)

    # In đánh giá
    print(f"\n>>> TỈ LỆ CHIA: {ratio_name} <<<")
    print(f"Accuracy (Train): {train_acc:.4f}")
    print(f"Accuracy (Test):  {val_acc:.4f}")
    print(f"Chênh lệch accuracy (Train-Test): {diff:.4f}")
    print('Classification Report (Test):')
    print(clf_report)
    print('Confusion Matrix (Test):')
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()
    name = ''
    if model == lr:
        name = 'Logistic Regression'
    else:
        name = "Naive Bayes"
    return {
        "Tỉ lệ chia": ratio_name,
        "Loại dữ liệu": data_type,
        "Mô hình": name,
        "Accuracy (Train)": round(train_acc, 4),
        "Accuracy (Test)": round(val_acc, 4),
        "Recall (Macro)": round(recall, 4),
        "F1-score (Macro)": round(f1, 4),
        "Chênh lệch accuracy (Train-Test)": round(diff, 4),
        "Classification Report (Test)": clf_report,
        "Confusion Matrix (Test)": cm
    }

# %% [markdown]
# #### 5.2.3.1. Mô hình Logistic Regression

# %% [markdown]
# ##### 5.2.3.1.1. Phân loại với dữ liệu gốc

# %%
# Nơi lưu kết quả
results_lr_org_list = []

print("HUẤN LUYỆN TRÊN DỮ LIỆU GỐC")

for ratio in ratios:
    test_size = ratio["test_size"]
    ratio_name = ratio["name"]
        
    # Chia dữ liệu
    X_train_raw, X_test_raw, y_train, y_test = train_test_split(
        X_classifier, y_classifier,
        test_size=test_size,
        random_state=105,
        stratify=y_classifier
    )
    
    # Chuẩn hóa
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_raw)
    X_test_scaled = scaler.transform(X_test_raw)
    lr = LogisticRegression(
        multi_class='multinomial',
        solver='sag',
        max_iter=1000,
        random_state=42
    )
    # Đánh giá dữ liệu gốc
    result_orig = evaluate_model(
        model=lr,
        X_train=X_train_scaled,
        X_test=X_test_scaled,
        y_train=y_train,
        y_test=y_test,
        data_type="Dữ liệu gốc",
        ratio_name=ratio_name
    )
    results_lr_org_list.append(result_orig)
# Out:
# HUẤN LUYỆN TRÊN DỮ LIỆU GỐC
#
# >>> TỈ LỆ CHIA: 4:1 (80/20) <<<
# Accuracy (Train): 0.8191
# Accuracy (Test):  0.7874
# Chênh lệch accuracy (Train-Test): 0.0317
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#         Thấp       0.90      0.90      0.90       195
#   Trung bình       0.68      0.70      0.69       195
#          Cao       0.78      0.76      0.77       198
#
#     accuracy                           0.79       588
#    macro avg       0.79      0.79      0.79       588
# weighted avg       0.79      0.79      0.79       588
#
# Confusion Matrix (Test):
# >>> TỈ LỆ CHIA: 7:3 (70/30) <<<
# Accuracy (Train): 0.8249
# Accuracy (Test):  0.8005
# Chênh lệch accuracy (Train-Test): 0.0244
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#         Thấp       0.91      0.90      0.91       292
#   Trung bình       0.71      0.71      0.71       293
# ...

# %% [markdown]
# ##### 5.2.3.1.2. Phân loại với dữ liệu giảm chiều

# %%
# Nơi lưu kết quả
results_lr_pca_list = []

print("HUẤN LUYỆN TRÊN DỮ LIỆU SAU PCA (1/3 chiều)")

for ratio in ratios:
    test_size = ratio["test_size"]
    ratio_name = ratio["name"]
    
    # Chia dữ liệu 
    X_train_raw, X_test_raw, y_train, y_test = train_test_split(
        X_classifier, y_classifier,
        test_size=test_size,
        random_state=105,
        stratify=y_classifier
    )
    
    # Chuẩn hóa
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_raw)
    X_test_scaled = scaler.transform(X_test_raw)
    
    # Giảm chiều PCA
    n_components = max(1, X_train_raw.shape[1] // 3)
    pca = PCA(n_components=n_components, random_state=42)
    X_train_pca = pca.fit_transform(X_train_scaled)
    X_test_pca  = pca.transform(X_test_scaled)
    lr = LogisticRegression(
        multi_class='multinomial',
        solver='sag',
        max_iter=1000,
        random_state=42
    )
    # Đánh giá dữ liệu PCA
    result_pca = evaluate_model(
        model=lr,
        X_train=X_train_pca,
        X_test=X_test_pca,
        y_train=y_train,
        y_test=y_test,
        data_type="Sau PCA (1/3 chiều)",
        ratio_name=ratio_name
    )
    results_lr_pca_list.append(result_pca)
# Out:
# HUẤN LUYỆN TRÊN DỮ LIỆU SAU PCA (1/3 chiều)
#
# >>> TỈ LỆ CHIA: 4:1 (80/20) <<<
# Accuracy (Train): 0.7877
# Accuracy (Test):  0.7415
# Chênh lệch accuracy (Train-Test): 0.0462
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#         Thấp       0.89      0.86      0.88       195
#   Trung bình       0.61      0.65      0.63       195
#          Cao       0.74      0.72      0.73       198
#
#     accuracy                           0.74       588
#    macro avg       0.75      0.74      0.74       588
# weighted avg       0.75      0.74      0.74       588
#
# Confusion Matrix (Test):
# >>> TỈ LỆ CHIA: 7:3 (70/30) <<<
# Accuracy (Train): 0.7860
# Accuracy (Test):  0.7540
# Chênh lệch accuracy (Train-Test): 0.0320
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#         Thấp       0.89      0.86      0.88       292
#   Trung bình       0.63      0.68      0.65       293
# ...

# %% [markdown]
# ##### 5.2.3.1.4. Kết quả

# %%
results_lr_list = results_lr_org_list + results_lr_pca_list
results_df = pd.DataFrame(results_lr_list)
results_df = results_df.sort_values(by="Accuracy (Test)", ascending=False).reset_index(drop=True)

print("\nBẢNG TỔNG HỢP KẾT QUẢ")
display(results_df[[
    "Tỉ lệ chia", "Loại dữ liệu", "Mô hình",
    "Accuracy (Train)", "Accuracy (Test)", "Chênh lệch accuracy (Train-Test)"
]])
# Out:
# BẢNG TỔNG HỢP KẾT QUẢ
#     Tỉ lệ chia         Loại dữ liệu              Mô hình  Accuracy (Train)  \
# 0  7:3 (70/30)          Dữ liệu gốc  Logistic Regression            0.8249
# 1  6:4 (60/40)          Dữ liệu gốc  Logistic Regression            0.8309
# 2  4:1 (80/20)          Dữ liệu gốc  Logistic Regression            0.8191
# 3  6:4 (60/40)  Sau PCA (1/3 chiều)  Logistic Regression            0.7911
# 4  7:3 (70/30)  Sau PCA (1/3 chiều)  Logistic Regression            0.7860
# 5  4:1 (80/20)  Sau PCA (1/3 chiều)  Logistic Regression            0.7877
#
#    Accuracy (Test)  Chênh lệch accuracy (Train-Test)
# 0           0.8005                            0.0244
# 1           0.7917                            0.0392
# 2           0.7874                            0.0317
# 3           0.7611                            0.0301
# 4           0.7540                            0.0320
# 5           0.7415                            0.0462

# %%
order = ["4:1 (80/20)", "7:3 (70/30)", "6:4 (60/40)"]
results_df['Tỉ lệ chia'] = pd.Categorical(
    results_df['Tỉ lệ chia'],
    categories=order,
    ordered=True
)
results_df = results_df.sort_values('Tỉ lệ chia')

ratios_split = results_df["Tỉ lệ chia"].unique()
data_types = results_df["Loại dữ liệu"].unique()

x = np.arange(len(ratios_split))
width = 0.35

plt.figure(figsize=(10, 6))   # 👈 đúng kiểu đã học

for i, dtype in enumerate(data_types):
    subset = results_df[results_df["Loại dữ liệu"] == dtype]
    plt.bar(
        x + i * width,
        subset.sort_values("Tỉ lệ chia")["Accuracy (Test)"],
        width,
        label=dtype
    )

plt.xticks(x + width / 2, ratios_split)
plt.xlabel("Tỉ lệ chia (Train/Test)")
plt.ylabel("Accuracy (Test)")
plt.title(
    "So sánh Test Accuracy theo tỉ lệ chia dữ liệu",
    fontsize=14
)

plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=results_df, x='Tỉ lệ chia', y='Chênh lệch accuracy (Train-Test)', hue='Loại dữ liệu', palette='husl')
plt.axhline(0.05, color='red', linestyle='--', linewidth=2, label='Ngưỡng overfit')
plt.title('So sánh độ chênh lệch Accuracy (Train - Test) theo tỉ lệ chia', fontsize=14, fontweight='bold')
plt.ylabel('Δ Accuracy (Train - Test)', fontsize=12)
plt.xlabel('Tỉ lệ Train:Test', fontsize=12)
plt.legend(title='Loại dữ liệu', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 5.2.3.1.5. Đánh giá, so sánh

# %% [markdown]
# - So sánh giữa các tỷ lệ chia dữ liệu:
#   - Tỷ lệ 7:3 và 8:2 (4:1):
#     - Thường cho kết quả ổn định nhất
#     - Tập huấn luyện đủ lớn để mô hình học được các quy luật tổng quát của dữ liệu
#   - Tỷ lệ 6:4:
#     - Độ chính xác (Accuracy) có xu hướng giảm nhẹ
#     - Tập huấn luyện bị thu hẹp
#     - Mô hình dễ rơi vào tình trạng thiếu khớp (underfitting) với các đặc trưng phức tạp
#
# - So sánh giữa Dữ liệu Gốc và Dữ liệu Giảm chiều (PCA 1/3):
#   - Dữ liệu gốc:
#     - Độ chính xác cao hơn
#     - Giữ lại toàn bộ thuộc tính
#   - Dữ liệu PCA (giảm còn ~7 chiều):
#     - Độ chính xác giảm khoảng 5–15% so với dữ liệu gốc
#     - Thời gian huấn luyện nhanh hơn đáng kể
#     - Mô hình ít phức tạp hơn
#
# - Nhận xét overfit:
#   - Tất cả các giá trị chênh lệch đều dưới ngưỡng overfit 0.05
#   - Không có dấu hiệu overfit nghiêm trọng ở bất kỳ trường hợp nào

# %% [markdown]
# #### 5.2.3.2. Mô hình phân loại Naive Bayes

# %% [markdown]
# ##### 5.2.3.2.1. Phân loại với dữ liệu gốc

# %%
print(ratios)
print("Bắt đầu với DỮ LIỆU GỐC\n" + "="*50) 
result_nb_org =[]

for ratio in ratios:
    test_size = ratio["test_size"]
    ratio_name = ratio["name"]
        
    # Chia dữ liệu
    X_train_naive_bayes, X_test_naive_bayes, y_train_naive_bayes, y_test_naive_bayes = train_test_split(
        X_classifier, y_classifier, test_size=test_size, random_state=105,stratify=y_classifier
    )
    
    scaler =  StandardScaler()
    X_train_scaled_naive_bayes =  scaler.fit_transform(X_train_naive_bayes)
    X_test_scaled_naive_bayes = scaler.transform(X_test_naive_bayes)
    gb = GaussianNB()   
    # Đánh giá dữ liệu gốc
    result_nb = evaluate_model(gb,X_train_scaled_naive_bayes,X_test_scaled_naive_bayes,y_train_naive_bayes,y_test_naive_bayes,"Dữ liệu gốc",ratio_name)
    result_nb_org.append(result_nb)
# Out:
# [{'name': '4:1 (80/20)', 'test_size': 0.2}, {'name': '7:3 (70/30)', 'test_size': 0.3}, {'name': '6:4 (60/40)', 'test_size': 0.4}]
# Bắt đầu với DỮ LIỆU GỐC
# ...
#
# >>> TỈ LỆ CHIA: 4:1 (80/20) <<<
# Accuracy (Train): 0.6983
# Accuracy (Test):  0.6973
# Chênh lệch accuracy (Train-Test): 0.0010
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#         Thấp       0.68      0.96      0.80       195
#   Trung bình       0.76      0.28      0.41       195
#          Cao       0.70      0.85      0.77       198
#
#     accuracy                           0.70       588
#    macro avg       0.71      0.70      0.66       588
# weighted avg       0.71      0.70      0.66       588
#
# Confusion Matrix (Test):
# >>> TỈ LỆ CHIA: 7:3 (70/30) <<<
# Accuracy (Train): 0.7033
# Accuracy (Test):  0.6871
# Chênh lệch accuracy (Train-Test): 0.0162
# Classification Report (Test):
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# ##### 5.2.3.2.2. Phân loại với dữ liệu giảm chiều

# %%
print("HUẤN LUYỆN TRÊN DỮ LIỆU SAU PCA (1/3 chiều)")
result_nb_pca = []
    
for ratio in ratios:
    test_size = ratio["test_size"]
    ratio_name = ratio["name"]
    
    # Chia dữ liệu 
    X_train_pca_naive_bayes, X_test_pca_naive_bayes, y_train_pca_naive_bayes, y_test_pca_naive_bayes = train_test_split(
        X_classifier, y_classifier, test_size=test_size,random_state=105,stratify=y_classifier
    )
    
    scaler = StandardScaler()
    X_train_scaled_naive_bayes = scaler.fit_transform(X_train_pca_naive_bayes)
    X_test_scaled_naive_bayes = scaler.transform(X_test_pca_naive_bayes)
    
    # Giảm chiều PCA
    n_components = max(1, X_train_pca_naive_bayes.shape[1] // 3)
    pca = PCA(n_components=n_components, random_state=42)
    X_train_pca_nb = pca.fit_transform(X_train_scaled_naive_bayes)
    X_test_pca_nb  = pca.transform(X_test_scaled_naive_bayes)
    gb = GaussianNB()    
    # Đánh giá dữ liệu PCA
    result_pca_nb = evaluate_model(
        model=gb,
        X_train=X_train_pca_nb,
        X_test=X_test_pca_nb,
        y_train=y_train_pca_naive_bayes,
        y_test=y_test_pca_naive_bayes,
        data_type="Sau PCA (1/3 chiều)",
        ratio_name=ratio_name
    )
    result_nb_pca.append(result_pca_nb)
# Out:
# HUẤN LUYỆN TRÊN DỮ LIỆU SAU PCA (1/3 chiều)
#
# >>> TỈ LỆ CHIA: 4:1 (80/20) <<<
# Accuracy (Train): 0.6715
# Accuracy (Test):  0.6565
# Chênh lệch accuracy (Train-Test): 0.0150
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#         Thấp       0.81      0.69      0.75       195
#   Trung bình       0.50      0.72      0.59       195
#          Cao       0.80      0.56      0.65       198
#
#     accuracy                           0.66       588
#    macro avg       0.70      0.66      0.66       588
# weighted avg       0.70      0.66      0.66       588
#
# Confusion Matrix (Test):
# >>> TỈ LỆ CHIA: 7:3 (70/30) <<<
# Accuracy (Train): 0.6741
# Accuracy (Test):  0.6633
# Chênh lệch accuracy (Train-Test): 0.0109
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#         Thấp       0.83      0.68      0.75       292
#   Trung bình       0.50      0.74      0.60       293
# ...

# %% [markdown]
# ##### 5.2.3.2.3. Kết quả

# %%
results_nb_list = result_nb_org + result_nb_pca
results_nb_df = pd.DataFrame(results_nb_list)
results_nb_df = results_nb_df.sort_values(by="Accuracy (Test)", ascending=False).reset_index(drop=True)


print("\nBẢNG TỔNG HỢP KẾT QUẢ")
display(results_nb_df[[
    "Tỉ lệ chia", "Loại dữ liệu", "Mô hình",
    "Accuracy (Train)", "Accuracy (Test)", "Chênh lệch accuracy (Train-Test)"
]])
# Out:
# BẢNG TỔNG HỢP KẾT QUẢ
#     Tỉ lệ chia         Loại dữ liệu      Mô hình  Accuracy (Train)  \
# 0  6:4 (60/40)          Dữ liệu gốc  Naive Bayes            0.7344
# 1  4:1 (80/20)          Dữ liệu gốc  Naive Bayes            0.6983
# 2  7:3 (70/30)          Dữ liệu gốc  Naive Bayes            0.7033
# 3  7:3 (70/30)  Sau PCA (1/3 chiều)  Naive Bayes            0.6741
# 4  4:1 (80/20)  Sau PCA (1/3 chiều)  Naive Bayes            0.6715
# 5  6:4 (60/40)  Sau PCA (1/3 chiều)  Naive Bayes            0.6708
#
#    Accuracy (Test)  Chênh lệch accuracy (Train-Test)
# 0           0.7151                            0.0193
# 1           0.6973                            0.0010
# 2           0.6871                            0.0162
# 3           0.6633                            0.0109
# 4           0.6565                            0.0150
# 5           0.6565                            0.0144

# %%
order = ["4:1 (80/20)", "7:3 (70/30)", "6:4 (60/40)"]
results_nb_df['Tỉ lệ chia'] = pd.Categorical(
    results_nb_df['Tỉ lệ chia'],
    categories=order,
    ordered=True
)
results_nb_df = results_nb_df.sort_values('Tỉ lệ chia')

ratios_split = results_nb_df["Tỉ lệ chia"].unique()
data_types = results_nb_df["Loại dữ liệu"].unique()

x = np.arange(len(ratios_split))
width = 0.35

plt.figure(figsize=(10, 6)) 

for i, dtype in enumerate(data_types):
    subset = results_nb_df[results_nb_df["Loại dữ liệu"] == dtype]
    plt.bar(
        x + i * width,
        subset.sort_values("Tỉ lệ chia")["Accuracy (Test)"],
        width,
        label=dtype
    )

plt.xticks(x + width / 2, ratios_split)
plt.xlabel("Tỉ lệ chia (Train/Test)")
plt.ylabel("Accuracy (Test)")
plt.title(
    "So sánh Test Accuracy theo tỉ lệ chia dữ liệu\n(Naive Bayes)",
    fontsize=14
)

plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=results_nb_df, x='Tỉ lệ chia', y='Chênh lệch accuracy (Train-Test)', hue='Loại dữ liệu', palette='husl')
plt.axhline(0.05, color='red', linestyle='--', linewidth=2, label='Ngưỡng overfit')
plt.title('So sánh độ chênh lệch Accuracy (Train - Test) theo tỉ lệ chia', fontsize=14, fontweight='bold')
plt.ylabel('Δ Accuracy (Train - Test)', fontsize=12)
plt.xlabel('Tỉ lệ Train:Test', fontsize=12)
plt.legend(title='Loại dữ liệu', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 5.2.3.2.4. Đánh giá, so sánh

# %% [markdown]
# - So sánh giữa các tỷ lệ chia dữ liệu:
#
#     - Tỷ lệ 7:3 và 8:2 (4:1): Hai tỷ lệ này cho kết quả ổn định, với Accuracy trên tập kiểm tra chỉ thay đổi rất nhỏ so với các tỷ lệ khác. Việc tập huấn luyện đủ lớn giúp mô hình Gaussian Naive Bayes học được các đặc trưng tổng quát của dữ liệu, trong khi tập kiểm tra vẫn đảm bảo khả năng đánh giá hiệu năng mô hình.
#     - Tỷ lệ 6:4: Mặc dù kích thước tập huấn luyện nhỏ hơn, Accuracy trên tập kiểm tra lại nhỉnh hơn nhẹ so với các tỷ lệ 7:3 và 8:2. Tuy nhiên, sự khác biệt này là không đáng kể và nhiều khả năng xuất phát từ tính ngẫu nhiên của quá trình chia dữ liệu cũng như việc tập kiểm tra lớn hơn giúp kết quả đánh giá ổn định hơn. Do đó, không thể kết luận rằng tỷ lệ 6:4 cho hiệu năng vượt trội hơn các tỷ lệ còn lại.
# - So sánh giữa Dữ liệu Gốc và Dữ liệu Giảm chiều (PCA – giữ 1/3 số chiều):
#
#     - Dữ liệu gốc: Mô hình đạt độ chính xác cao hơn do toàn bộ các thuộc tính ban đầu được giữ lại, giúp bảo toàn đầy đủ thông tin cần thiết cho quá trình phân loại.
#     - Dữ liệu sau PCA (giảm còn khoảng 1/3 số chiều): Độ chính xác giảm nhẹ so với dữ liệu gốc. Tuy nhiên, mô hình trở nên đơn giản hơn, ổn định hơn và ít bị ảnh hưởng bởi nhiễu, đồng thời khoảng chênh lệch giữa Accuracy huấn luyện và kiểm tra được thu hẹp.

# %% [markdown]
# ### 5.2.4. Tổng quan so sánh 2 mô hình

# %%
all_results = (
    results_lr_org_list
    + results_lr_pca_list
    + result_nb_org
    + result_nb_pca
)

df = pd.DataFrame(all_results)

df_selected = df[
    [
        "Tỉ lệ chia",
        "Loại dữ liệu",
        "Mô hình",
        "Accuracy (Test)",
        "F1-score (Macro)"
    ]
]

df_selected

table_df = df[
    ["Tỉ lệ chia", "Loại dữ liệu", "Mô hình", "Accuracy (Test)", "F1-score (Macro)"]
].copy()

table_df["Accuracy (Test)"] = table_df["Accuracy (Test)"].round(4)
table_df["F1-score (Macro)"] = table_df["F1-score (Macro)"].round(4)

fig, ax = plt.subplots(figsize=(14, 6))
ax.axis("off")

table = ax.table(
    cellText=table_df.values,
    colLabels=table_df.columns,
    loc="center",
    cellLoc="center"
)

table.auto_set_font_size(False)
table.set_fontsize(11)
table.scale(1, 1.5)

# Làm header đậm + nền xám
for (row, col), cell in table.get_celld().items():
    if row == 0:
        cell.set_text_props(weight="bold")
        cell.set_facecolor("#E6E6E6")

plt.title(
    "Bảng tổng hợp kết quả đánh giá mô hình\n(Accuracy & F1-score)",
    fontsize=16,
    fontweight="bold",
    pad=20
)

plt.show()

# %% [markdown]
# #### 5.2.4.1 Vẽ các biểu đồ để so sánh 2 mô hình dựa trên accuraccy và f1-score

# %% [markdown]
# ##### So sánh accurracy trên dữ liệu gốc

# %%
subset = df[df["Loại dữ liệu"] == "Dữ liệu gốc"]

ratios_split = subset["Tỉ lệ chia"].unique()
models = subset["Mô hình"].unique()

x = np.arange(len(ratios_split))
width = 0.35

plt.figure(figsize=(10, 6))

for i, model in enumerate(models):
    model_data = subset[subset["Mô hình"] == model]
    plt.bar(
        x + i * width,
        model_data.sort_values("Tỉ lệ chia")["Accuracy (Test)"],
        width,
        label=model
    )

plt.xticks(x + width / 2, ratios_split)
plt.xlabel("Tỉ lệ chia (Train/Test)")
plt.ylabel("Accuracy (Test)")
plt.title("So sánh Accuracy giữa các mô hình\n(Dữ liệu gốc – nhiều tỉ lệ chia)")
plt.ylim(0, 1)
plt.legend()
plt.show()

# %% [markdown]
# ##### So sánh accuraccy trên tập dữ liệu sau khi pca

# %%
subset = df[df["Loại dữ liệu"] == "Sau PCA (1/3 chiều)"]

ratios_split = subset["Tỉ lệ chia"].unique()
models = subset["Mô hình"].unique()

x = np.arange(len(ratios_split))
width = 0.35

plt.figure(figsize=(10, 6))

for i, model in enumerate(models):
    model_data = subset[subset["Mô hình"] == model]
    plt.bar(
        x + i * width,
        model_data.sort_values("Tỉ lệ chia")["Accuracy (Test)"],
        width,
        label=model
    )

plt.xticks(x + width / 2, ratios_split)
plt.xlabel("Tỉ lệ chia (Train/Test)")
plt.ylabel("Accuracy (Test)")
plt.title("So sánh Accuracy giữa các mô hình\n(Sau PCA (1/3 chiều) – nhiều tỉ lệ chia)")
plt.ylim(0, 1)
plt.legend()
plt.show()

# %% [markdown]
# ##### So sánh chỉ số f1-score trên tập dữ liệu gốc

# %%
subset = df[df["Loại dữ liệu"] == "Dữ liệu gốc"]

# Sắp xếp tỉ lệ chia theo thứ tự logic
ratios_split = ["6:4 (60/40)", "7:3 (70/30)", "4:1 (80/20)"]
models = subset["Mô hình"].unique()

x = np.arange(len(ratios_split))
width = 0.35

plt.figure(figsize=(10, 6))

for i, model in enumerate(models):
    model_data = subset[subset["Mô hình"] == model] \
                    .set_index("Tỉ lệ chia") \
                    .loc[ratios_split]

    plt.bar(
        x + i * width,
        model_data["F1-score (Macro)"],
        width,
        label=model
    )

plt.xticks(x + width / 2, ratios_split)
plt.xlabel("Tỉ lệ chia (Train/Test)")
plt.ylabel("F1-score (Macro)")
plt.title("So sánh F1-score giữa các mô hình\n(Dữ liệu gốc – nhiều tỉ lệ chia)")
plt.ylim(0, 1)
plt.legend()
plt.show()

# %% [markdown]
# ##### So sánh chỉ số f1-score trên tập dữ liệu đã pca

# %%
subset = df[df["Loại dữ liệu"] == "Sau PCA (1/3 chiều)"]

# Sắp xếp tỉ lệ chia theo thứ tự logic
ratios_split = ["6:4 (60/40)", "7:3 (70/30)", "4:1 (80/20)"]
models = subset["Mô hình"].unique()

x = np.arange(len(ratios_split))
width = 0.35

plt.figure(figsize=(10, 6))

for i, model in enumerate(models):
    model_data = subset[subset["Mô hình"] == model] \
                    .set_index("Tỉ lệ chia") \
                    .loc[ratios_split]

    plt.bar(
        x + i * width,
        model_data["F1-score (Macro)"],
        width,
        label=model
    )

plt.xticks(x + width / 2, ratios_split)
plt.xlabel("Tỉ lệ chia (Train/Test)")
plt.ylabel("F1-score (Macro)")
plt.title("So sánh F1-score giữa các mô hình\n(Sau PCA (1/3 chiều) – nhiều tỉ lệ chia)")
plt.ylim(0, 1)
plt.legend()
plt.show()

# %% [markdown]
# #### 5.2.4.2 Đánh giá tổng quát hai mô hình
#
# Nhìn chung, **Logistic Regression** cho kết quả **tốt và ổn định hơn** so với **Naive Bayes** trên tất cả các tỉ lệ chia và cả hai loại dữ liệu. Mô hình này đạt Accuracy và F1-score cao hơn, đồng thời các chỉ số khá cân bằng, cho thấy khả năng tổng quát hóa tốt.
#
# Trong khi đó, **Naive Bayes** có hiệu năng **thấp hơn** và nhạy cảm hơn với cách chia dữ liệu. F1-score thường thấp hơn Accuracy, cho thấy mô hình gặp khó khăn khi dự đoán các lớp ít mẫu.
#
# Trong bài toán này, **Logistic Regression là lựa chọn phù hợp hơn Naive Bayes** về mặt hiệu suất và độ ổn định.
